# %% [markdown]
# # Intro
# In order to use this package while it is in development, the script must be inside the package. This may remain in the final as an example of use.
# This package is developed in order to automate segmentation defects in fatigue fracture surfaces. Others have found great success using the Unet architecture, so an implimentation supporting an numbe rof input and output classes was developed. Multiple imput classes are supported so that height map data can be appended to the image data for improved characterization, and multiple output classes are supported so that multiple defect classes can be supported.

# %% [markdown]
# # Forming Dataframe

# %% [markdown]
# ## EP05+EP07 - DataFrame

# %%
import pandas as pd
EP05 = pd.read_excel('/home/aml334/CSE_MSE_RXF131/staging/mds3/fractography/EP05/EP05 Fractographical Data_cycles_added.xlsx')
print(EP05.columns)
print(EP05.head(3))
# Out:
# Index(['Sample#', 'Type', 'a (mm)', 'a/b (b=5mm)', 'σ (Mpa)',
#        'F (Empirical formula)', 'Kc (MPa√m)', 'Cycles'],
#       dtype='object')
#       Sample#     Type    a (mm)  a/b (b=5mm) σ (Mpa)  F (Empirical formula)  \
# 0  EP05-V31-1  Keyhole  1.573034     0.314607     900               1.136909
# 1  EP05-V31-2  Keyhole  1.259740     0.251948     900               1.081787
# 2  EP05-V32-1  Keyhole  2.445783     0.489157     667               1.461674
#
#    Kc (MPa√m)    Cycles
# 0   71.930330   56710.0
# 1   61.249117   40049.0
# 2   85.459481  228510.0

# %%
EP07 = pd.read_excel('/home/aml334/CSE_MSE_RXF131/staging/mds3/fractography/EP07/EP07-Fractographical Data.xlsx')
print(EP07.columns)
print(EP07.head(3))
# Out:
# Index(['Sample#', 'Type', 'a (mm)', 'a/b (b=5mm)', 'σ (Mpa)',
#        'F (Empirical formula)', 'Kc (MPa√m)'],
#       dtype='object')
#       Sample#     Type    a (mm) a/b (b=5mm)  σ (Mpa) F (Empirical formula)  \
# 0  EP07-V31-1  Keyhole  1.056872    0.211374    667.0              1.057993
# 1  EP07-V31-2  Keyhole  1.916517    0.383303    533.0              1.227906
# 2  EP07-V32-1  Keyhole  1.545455    0.309091    667.0              1.131095
#
#   Kc (MPa√m)
# 0  40.662573
# 1  50.783612
# 2  52.568794

# %%
initation_sites = pd.read_csv('/mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractography/raw_initiation_only.csv')

# %% [markdown]
# ## Matching Processing Conditions

# %%
process_parameters = pd.read_csv('/home/aml334/CSE_MSE_RXF131/staging/mds3/fractography/variable-process-parameters.csv')
print(process_parameters)
# Out:
#   Test ID  Process Regime  P (W)  V (mm/s)
# 0     PV2         Keyhole    370       600
# 1     PV3         Keyhole    370       800
# 2     PV4  Process Window    330      1585
# 3     PV5  Process Window    370      1800
# 4     PV6  Process Window    370      1400
# 5     PV7             LOF    150      1200
# 6     PV8             LOF    370      3000
# 7     PV9             LOF    370      2000
# 8     PVE  Process Window    280      1200

# %%
def name_to_power(name:str, position:int):
    for idx, option in enumerate(process_parameters['Test ID']):
        if(option[2] == name[position]):
            return process_parameters['P (W)'][idx]
def name_to_velocity(name:str,position:int):
    for idx, option in enumerate(process_parameters['Test ID']):
        if(option[2] == name[position]):
            return process_parameters['V (mm/s)'][idx]
print(name_to_power(str(4),0))
print(name_to_velocity(str(2),0))
# Out:
# 330
# 600

# %%
output = pd.concat([EP05,EP07])[['Sample#','Cycles','σ (Mpa)']]

output['Load Ratio (R)'] = 0.1
output['Power (W)'] = output['Sample#'].apply(lambda row:name_to_power(row,6))
output['Velocity (mm/s)'] = output['Sample#'].apply(lambda row: name_to_velocity(row,6))
output.head(3)
# Out:
#       Sample#    Cycles σ (Mpa)  Load Ratio (R)  Power (W)  Velocity (mm/s)
# 0  EP05-V31-1   56710.0     900             0.1        370              800
# 1  EP05-V31-2   40049.0     900             0.1        370              800
# 2  EP05-V32-1  228510.0     667             0.1        370              800

# %%
images = pd.read_csv('/home/aml334/CSE_MSE_RXF131/staging/mds3/fractography/rawdata.csv')
images = images[images['entry']=='stitch']
images.rename(columns={'raw_name':'stitched_img_path'},inplace=True) 
images['Sample#'] = images['raw_basename'].str[:-13]
#print(images.head(3))
#print(images['raw_basename'])
results = pd.merge(output,images,on='Sample#')
print(results)
print(results.columns)
print(len(results))
results.to_csv('/home/aml334/CSE_MSE_RXF131/staging/mds3/fractography/schema_data.csv')
# i = results['σ (Mpa)'].idxmin()
# print(results['Sample#'][i])
# print(results['σ (Mpa)'][i])
# print(results['Cycles'][i])
# Out:
#        Sample#     Cycles σ (Mpa)  Load Ratio (R)  Power (W)  Velocity (mm/s)  \
# 0   EP05-V31-1    56710.0     900             0.1        370              800
# 1   EP05-V31-2    40049.0     900             0.1        370              800
# 2   EP05-V32-1   228510.0     667             0.1        370              800
# 3   EP05-V32-2    89920.0     667             0.1        370              800
# 4   EP05-V33-2    46231.0     533             0.1        370              800
# 5   EP05-V41-1    33175.0    1067             0.1        330             1585
# 6   EP05-V42-1    50292.0     900             0.1        330             1585
# 7   EP05-V42-2    76046.0     900             0.1        330             1585
# 8   EP05-V51-1    40232.0    1067             0.1        370             1800
# 9   EP05-V51-2    76224.0     900             0.1        370             1800
# 10  EP05-V52-2    18964.0    1200             0.1        370             1800
# 11  EP05-V64-1  2419759.0    1200             0.1        370             1400
# 12  EP05-V64-2        NaN       ?             0.1        370             1400
# 13  EP05-V71-1   144112.0     400             0.1        150             1200
# 14  EP05-V72-1   348649.0     300             0.1        150             1200
# 15  EP05-V81-1   163946.0     400             0.1        370             3000
# 16  EP05-V81-2    55171.0     533             0.1        370             3000
# 17  EP05-V84-1   397258.0     300             0.1        370             3000
# 18  EP05-V84-2   951149.0     300             0.1        370             3000
# 19  EP05-V91-1   127485.0     667             0.1        370             2000
# 20  EP05-V91-2    35822.0     900             0.1        370             2000
# 21  EP05-V92-1   363834.0     533             0.1        370             2000
# 22  EP05-V92-2   465584.0     533             0.1        370             2000
# 23  EP05-V93-1    26019.0    1067             0.1        370             2000
# 24  EP05-V93-2    19024.0    1067             0.1        370             2000
# 25  EP05-VE4-2    34052.0    1200             0.1        280             1200
# 26  EP07-V31-1        NaN   667.0             0.1        370              800
# 27  EP07-V31-2        NaN   533.0             0.1        370              800
# 28  EP07-V32-2        NaN   533.0             0.1        370              800
# 29  EP07-V34-1        NaN   900.0             0.1        370              800
# 30  EP07-V34-2        NaN   900.0             0.1        370              800
# 31  EP07-V42-1        NaN   900.0             0.1        330             1585
# 32  EP07-V51-2        NaN   667.0             0.1        370             1800
# 33  EP07-V64-2        NaN  1200.0             0.1        370             1400
# 34  EP07-V73-1        NaN   533.0             0.1        150             1200
# 35  EP07-V74-1        NaN   667.0             0.1        150             1200
# 36  EP07-V81-2        NaN   533.0             0.1        370             3000
# 37  EP07-V82-1        NaN   667.0             0.1        370             3000
# 38  EP07-V82-2        NaN   667.0             0.1        370             3000
# 39  EP07-V84-1        NaN   533.0             0.1        370             3000
# 40  EP07-V91-1        NaN   533.0             0.1        370             2000
# 41  EP07-V91-2        NaN     NaN             0.1        370             2000
# 42  EP07-V93-2        NaN   900.0             0.1        370             2000
# 43  EP07-V94-1        NaN   667.0             0.1        370             2000
# 44  EP07-V94-2        NaN   667.0             0.1        370             2000
# 45  EP07-VE4-1        NaN  1200.0             0.1        280             1200
# 46  EP07-VE4-2        NaN  1067.0             0.1        280             1200
#
#                                     stitched_img_path directory  \
# 0   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 1   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 2   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 3   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 4   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 5   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 6   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 7   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 8   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 9   /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 10  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 11  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 12  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 13  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 14  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 15  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 16  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 17  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 18  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 19  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 20  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 21  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 22  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 23  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 24  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 25  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP05
# 26  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 27  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 28  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 29  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 30  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 31  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 32  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 33  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 34  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 35  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 36  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 37  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 38  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 39  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 40  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 41  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 42  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 43  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 44  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 45  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
# 46  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...      EP07
#
#                raw_basename type series   entry
# 0   EP05-V31-1-STITCHED.tif  v31   ep05  stitch
# 1   EP05-V31-2-STITCHED.tif  v31   ep05  stitch
# 2   EP05-V32-1-STITCHED.tif  v32   ep05  stitch
# 3   EP05-V32-2-STITCHED.tif  v32   ep05  stitch
# 4   EP05-V33-2-stitched.tif  v33   ep05  stitch
# 5   EP05-V41-1-STITCHED.tif  v41   ep05  stitch
# 6   EP05-V42-1-STITCHED.tif  v42   ep05  stitch
# 7   EP05-V42-2-STITCHED.tif  v42   ep05  stitch
# 8   EP05-V51-1-STITCHED.tif  v51   ep05  stitch
# 9   EP05-V51-2-STITCHED.tif  v51   ep05  stitch
# 10  EP05-V52-2-STITCHED.tif  v52   ep05  stitch
# 11  EP05-V64-1-STITCHED.tif  v64   ep05  stitch
# 12  EP05-V64-2-STITCHED.tif  v64   ep05  stitch
# 13  EP05-V71-1-STITCHED.tif  v71   ep05  stitch
# 14  EP05-V72-1-STITCHED.tif  v72   ep05  stitch
# 15  EP05-V81-1-STITCHED.tif  v81   ep05  stitch
# 16  EP05-V81-2-STITCHED.tif  v81   ep05  stitch
# 17  EP05-V84-1-STITCHED.tif  v84   ep05  stitch
# 18  EP05-V84-2-STITCHED.tif  v84   ep05  stitch
# 19  EP05-V91-1-STITCHED.tif  v91   ep05  stitch
# 20  EP05-V91-2-STITCHED.tif  v91   ep05  stitch
# 21  EP05-V92-1-STITCHED.tif  v92   ep05  stitch
# 22  EP05-V92-2-STITCHED.tif  v92   ep05  stitch
# 23  EP05-V93-1-STITCHED.tif  v93   ep05  stitch
# 24  EP05-V93-2-STITCHED.tif  v93   ep05  stitch
# 25  EP05-VE4-2_stitched.tif  ve4   ep05  stitch
# 26  EP07-V31-1-stitched.tif  v31   ep07  stitch
# 27  EP07-V31-2_stitched.tif  v31   ep07  stitch
# 28  EP07-V32-2-STITCHED.tif  v32   ep07  stitch
# 29  EP07-V34-1-STITCHED.tif  v34   ep07  stitch
# 30  EP07-V34-2-STITCHED.tif  v34   ep07  stitch
# 31  EP07-V42-1-stitched.tif  v42   ep07  stitch
# 32  EP07-V51-2-STITCHED.tif  v51   ep07  stitch
# 33  EP07-V64-2_stitched.tif  v64   ep07  stitch
# 34  EP07-V73-1-STITCHED.tif  v73   ep07  stitch
# 35  EP07-V74-1-stitched.tif  v74   ep07  stitch
# 36  EP07-V81-2 STITCHED.tif  v81   ep07  stitch
# 37  EP07-V82-1-STITCHED.tif  v82   ep07  stitch
# 38  EP07-V82-2-STITCHED.tif  v82   ep07  stitch
# 39  EP07-V84-1_stitched.tif  v84   ep07  stitch
# 40  EP07-V91-1_stitched.tif  v91   ep07  stitch
# 41  EP07-V91-2-STITCHED.tif  v91   ep07  stitch
# 42  EP07-V93-2-STITCHED.tif  v93   ep07  stitch
# 43  EP07-V94-1-STITCHED.tif  v94   ep07  stitch
# 44  EP07-V94-2-STITCHED.tif  v94   ep07  stitch
# 45  EP07-VE4-1-stitched.tif  ve4   ep07  stitch
# 46  EP07-VE4-2-stitched.tif  ve4   ep07  stitch
# Index(['Sample#', 'Cycles', 'σ (Mpa)', 'Load Ratio (R)', 'Power (W)',
#        'Velocity (mm/s)', 'stitched_img_path', 'directory', 'raw_basename',
#        'type', 'series', 'entry'],
#       dtype='object')
# 47

# %% [markdown]
# Now that we have a dataframe, lets see how much redundancy theere is in the dataset.

# %% [markdown]
# ## Numerical Results (Brett DataFrame)

# %%
#Excel to Dataframe
Brett_spreadsheet = pd.ExcelFile('/mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractography/Trial_Brett_7_11_2024.xlsx')
excel_df=pd.DataFrame()
for worksheet in Brett_spreadsheet.sheet_names:
    excel_df = pd.concat([excel_df,pd.read_excel(Brett_spreadsheet,worksheet)])
print(excel_df.columns)

#Filter Based on Cycles
excel_df = excel_df[excel_df['Cycles '].notna()]
type_counts = excel_df['Cycles '].apply(type).value_counts()
print(type_counts)
excel_df = excel_df[excel_df['Cycles '].apply(lambda x: isinstance(x, int) or isinstance(x,float))]
excel_df['Cycles '] = excel_df['Cycles '].astype(int)
type_counts = excel_df['Cycles '].apply(type).value_counts()
print(type_counts)

#Filtering Based on BuildID
excel_df = excel_df[excel_df['Build ID'].notna()]

#Making key
excel_df['Sample#'] = excel_df['Build ID'] + '-'+excel_df['Build #'].astype(str).str.rstrip('.0')+'-'+excel_df['Test #'].astype(str).str.rstrip('.0')
# Out:
# Index(['Build ID', 'Build #', 'Test #', 'Retest', 'Project Name',
#        'Cleaning Status', 'Imaging Status', 'Defect Quantification Status',
#        'Scan Power (W)', 'Scan velocity (mm/s)', 'b (mm)', 'd (mm)', 'L (mm)',
#        'Tested?', 'Date Tested', 'Machine', 'P max (N)', 'P min (N)',
#        'R-ratio', 'σ max initiation (MPa)', 'Frequency (Hz)', 'Cycles ',
#        'Date Imaged', 'Initiation type', 'Surface or subsurface', 'Notes:',
#        'Hatch Spacing (mm)', 'Location:', 'Imaged?', 'Visible Defect?'],
#       dtype='object')
# Cycles
# <class 'float'>    315
# <class 'int'>       38
# <class 'str'>        1
# Name: count, dtype: int64
# Cycles
# <class 'int'>    353
# Name: count, dtype: int64
# /tmp/job.2076634.hpc/ipykernel_2317533/315560972.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   excel_df = pd.concat([excel_df,pd.read_excel(Brett_spreadsheet,worksheet)])
# /tmp/job.2076634.hpc/ipykernel_2317533/315560972.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   excel_df = pd.concat([excel_df,pd.read_excel(Brett_spreadsheet,worksheet)])
# /tmp/job.2076634.hpc/ipykernel_2317533/315560972.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   excel_df = pd.concat([excel_df,pd.read_excel(Brett_spreadsheet,worksheet)])
# /tmp/job.2076634.hpc/ipykernel_2317533/315560972.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   excel_df = pd.concat([excel_df,pd.read_excel(Brett_spreadsheet,worksheet)])

# %% [markdown]
# excel_df is not a resonably well constructed dsataframe that contains the testing conditions and numerical results for the samples. We can now explore this a bit, and latter merge with the image columns based on the identification columns, to get a more complete dataset.

# %%
excel_df['R-ratio'].value_counts()
excel_df['Hatch Spacing (mm)'].value_counts()
P_max = excel_df['P max (N)'].value_counts().idxmax()
most_common = excel_df[excel_df['P max (N)']==P_max]
print(len(most_common))
Scan_Power_max = most_common['Scan Power (W)'].value_counts().idxmax()
most_common = most_common[most_common['Scan Power (W)']==Scan_Power_max]
print(len(most_common))
Scan_Velocity_max = most_common['Scan velocity (mm/s)'].value_counts().idxmax()
most_common = most_common[most_common['Scan velocity (mm/s)']==Scan_Velocity_max]
print(most_common)


import matplotlib.pyplot as plt
plt.scatter(range(len(most_common)),most_common['Cycles '])
# Out:
# 86
# 51
#    Build ID Build #  Test #  Retest Project Name  Cleaning Status  \
# 0     CMU01    30.0     1.0     0.0         STRI              NaN
# 1     CMU01    30.0     2.0     0.0         STRI              NaN
# 24    CMU01    10.0     2.0     0.0          ULI              NaN
# 67    CMU01    30.0     1.0     0.0         STRI              NaN
# 68    CMU01    30.0     2.0     0.0         STRI              NaN
#
#     Imaging Status  Defect Quantification Status  Scan Power (W)  \
# 0              NaN                           NaN           370.0
# 1              NaN                           NaN           370.0
# 24             NaN                           NaN           370.0
# 67             NaN                           NaN           370.0
# 68             NaN                           NaN           370.0
#
#     Scan velocity (mm/s)  ...  Cycles   Date Imaged  Initiation type  \
# 0                 1000.0  ...  3763500          NaT              NaN
# 1                 1000.0  ...  7335546          NaT              NaN
# 24                1000.0  ...  6934765          NaT              NaN
# 67                1000.0  ...  3763500          NaT              NaN
# 68                1000.0  ...  7335546          NaT              NaN
#
#    Surface or subsurface Notes: Hatch Spacing (mm)  Location:  Imaged?  \
# 0                    NaN    NaN               0.14        NaN      NaN
# 1                    NaN    NaN               0.14        NaN      NaN
# 24                   NaN    NaN               0.14        NaN      NaN
# 67                   NaN    NaN               0.14        NaN      NaN
# 68                   NaN    NaN               0.14        NaN      NaN
#
#     Visible Defect?    Sample#
# 0               NaN  CMU01-3-1
# 1               NaN  CMU01-3-2
# 24              NaN  CMU01-1-2
# 67              NaN  CMU01-3-1
# 68              NaN  CMU01-3-2
#
# [5 rows x 31 columns]

# %% [markdown]
# From the above code, we can see that some of the samples had identical processing and testing conditions, but still varied by more than 3 million cycles, a pretty substantial range.

# %%
print('Total number of tests: '+str(len(excel_df[['P max (N)','Scan velocity (mm/s)','Scan Power (W)']])))
print('Total number of testing conditions: '+str(len(excel_df[['P max (N)','Scan velocity (mm/s)','Scan Power (W)']].drop_duplicates())))

import math
groups = excel_df.groupby(['P max (N)','Scan velocity (mm/s)','Scan Power (W)'])
#When run, the results are largely identical, so the simpler max-min will be used
# max_difference_cycles = []
# for name, group in groups:
#     if(len(group)>2):
#         no_retake = group[group['Retest']==float(0)]
#         try:
#             max_difference_cycles.append(math.log(abs(no_retake['Cycles '].median()-no_retake['Cycles '].mean())+1))
#         except ValueError:
#             print('In group: '+str(name)+' something werid is going on')
# plt.scatter(range(len(max_difference_cycles)),max_difference_cycles)

max_difference_cycles = []
for name, group in groups:
    if(len(group)>2):
        print(group)
        no_retake = group[group['Retest']==float(0)]
        try:
            max_difference_cycles.append(no_retake['Cycles '].max()-no_retake['Cycles '].min())
        except ValueError:
            print('In group: '+str(name)+' something werid is going on')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.hist(max_difference_cycles,bins=50)
ax2.scatter(range(len(max_difference_cycles)),max_difference_cycles)
# ax2.hist([math.log(x+10000000000) for x in max_difference_cycles],bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print('Total number of tests: '+str(len(excel_df[['P max (N)','Scan velocity (mm/s)','Scan Power (W)']])))
#       2 print('Total number of testing conditions: '+str(len(excel_df[['P max (N)','Scan velocity (mm/s)','Scan Power (W)']].drop_duplicates())))
#       4 import math
#
# NameError: name 'excel_df' is not defined

# %% [markdown]
# From the above code, we can see that the some of these testing conditions seem to have a largely bimodal distribution, there are testing conditions with basically 0 variation, and testing conditions with tons and tons of variation. Interestingly, this trend is maintained as the number of samples increase.
# Upon further investigations, the samples were not actaully close to 0, log removes any sortof clustering. So all of the samples have actaully quite a lot of variation.

# %%
plt.scatter(range(len(excel_df['Cycles '])),excel_df['Cycles '])

# %% [markdown]
# The distribution of variation of cycles accross the testing conditions and the graph of all cycles seem to be visually similar.
# Lets see if we can correlate differences in cycles within testing conditions to the differences in initiatingdefects.

# %%
print(excel_df['Sample#'].value_counts())
Sample_num_max = excel_df['Sample#'].value_counts().idxmax()
excel_df[excel_df['Sample#']==Sample_num_max]
# Out:
# Sample#
# CMU01-3-2     5
# CMU01-2-2     4
# CMU01-4-1     3
# CMU01-3-1     3
# CMU02-2-1     3
#              ..
# CMU01-8-2     1
# CMU01-9-2     1
# CMU01-1-1     1
# CMU01-11-2    1
# CMU01-12-1    1
# Name: count, Length: 287, dtype: int64
#    Build ID Build #  Test #  Retest Project Name  Cleaning Status  \
# 1     CMU01    30.0     2.0     0.0         STRI              NaN
# 6     CMU01     3.0     2.0     0.0          ULI              NaN
# 7     CMU01     3.0     2.0     1.0          ULI              NaN
# 8     CMU01     3.0     2.0     2.0          ULI              NaN
# 68    CMU01    30.0     2.0     0.0         STRI              NaN
#
#     Imaging Status  Defect Quantification Status  Scan Power (W)  \
# 1              NaN                           NaN           370.0
# 6              NaN                           NaN           370.0
# 7              NaN                           NaN           370.0
# 8              NaN                           NaN           370.0
# 68             NaN                           NaN           370.0
#
#     Scan velocity (mm/s)  ...   Cycles   Date Imaged  Initiation type  \
# 1                 1000.0  ...   7335546          NaT              NaN
# 6                 1150.0  ...  10000000          NaT              NaN
# 7                 1150.0  ...  10000000          NaT              NaN
# 8                 1150.0  ...   1545650          NaT              NaN
# 68                1000.0  ...   7335546          NaT              NaN
#
#    Surface or subsurface Notes: Hatch Spacing (mm)  Location:  Imaged?  \
# 1                    NaN    NaN               0.14        NaN      NaN
# 6                    NaN    NaN               0.14        NaN      NaN
# 7                    NaN    NaN               0.14        NaN      NaN
# 8                    NaN    NaN               0.14        NaN      NaN
# 68                   NaN    NaN               0.14        NaN      NaN
#
#     Visible Defect?    Sample#
# 1               NaN  CMU01-3-2
# 6               NaN  CMU01-3-2
# 7               NaN  CMU01-3-2
# 8               NaN  CMU01-3-2
# 68              NaN  CMU01-3-2
#
# [5 rows x 31 columns]

# %%
for name, group in excel_df.groupby(['Build ID', 'Build #','Test #']):
    print(str(group[['Retest','Sample#','Cycles ']]))
    # for idex, row in group.iterrows():
    #     if row['Retest']==float(1):
    #         print(group)
# Out:
#    Retest    Sample#  Cycles
# 1     0.0  CMU01-1-2  7969454
#    Retest    Sample#  Cycles
# 2     0.0  CMU01-2-1    49396
#    Retest    Sample#   Cycles
# 0     1.0  CMU01-2-2  10000000
# 3     0.0  CMU01-2-2  10000000
# 4     1.0  CMU01-2-2  10000000
#    Retest    Sample#  Cycles
# 5     0.0  CMU01-3-1   857305
#    Retest    Sample#   Cycles
# 6     0.0  CMU01-3-2  10000000
# 7     1.0  CMU01-3-2  10000000
# 8     2.0  CMU01-3-2   1545650
#     Retest    Sample#   Cycles
# 1      1.0  CMU01-4-1  10000000
# 9      0.0  CMU01-4-1  10000000
# 10     1.0  CMU01-4-1  10000000
#     Retest    Sample#  Cycles
# 11     0.0  CMU01-4-2  4036228
#     Retest    Sample#  Cycles
# 12     0.0  CMU01-5-1   302356
#     Retest    Sample#   Cycles
# 13     0.0  CMU01-5-2  10000000
# 14     1.0  CMU01-5-2     71525
#     Retest    Sample#   Cycles
# 15     0.0  CMU01-6-1  10000000
#     Retest    Sample#   Cycles
# 16     0.0  CMU01-6-2  10000000
#     Retest    Sample#   Cycles
# 2      0.0  CMU01-7-1  10000000
# 17     0.0  CMU01-7-1  10000000
#     Retest    Sample#  Cycles
# 18     0.0  CMU01-7-2    87830
#     Retest    Sample#  Cycles
# 19     0.0  CMU01-8-1    24473
#     Retest    Sample#  Cycles
# 20     0.0  CMU01-8-2   173087
#     Retest    Sample#   Cycles
# 3      0.0  CMU01-9-1  10000000
# 21     0.0  CMU01-9-1  10000000
#     Retest    Sample#  Cycles
# 22     0.0  CMU01-9-2   295212
#     Retest    Sample#  Cycles
# 23     0.0  CMU01-1-1   179537
#     Retest    Sample#  Cycles
# 24     0.0  CMU01-1-2  6934765
#     Retest     Sample#   Cycles
# 4      0.0  CMU01-11-1  10000000
# 25     0.0  CMU01-11-1  10000000
#     Retest     Sample#  Cycles
# 26     0.0  CMU01-11-2  9922343
#     Retest     Sample#  Cycles
# 27     0.0  CMU01-12-1   120283
#     Retest     Sample#   Cycles
# 28     0.0  CMU01-12-2  10000000
# 29     1.0  CMU01-12-2     45275
#     Retest     Sample#  Cycles
# 30     0.0  CMU01-13-1   141528
#     Retest     Sample#  Cycles
# 31     0.0  CMU01-13-2    51688
#     Retest     Sample#  Cycles
# 32     0.0  CMU01-14-1    85947
#     Retest     Sample#   Cycles
# 33     0.0  CMU01-14-2  10000000
#     Retest     Sample#  Cycles
# 34     0.0  CMU01-15-1  7504175
#     Retest     Sample#   Cycles
# 5      0.0  CMU01-15-2  10000000
# 35     0.0  CMU01-15-2  10000000
#     Retest     Sample#  Cycles
# 36     0.0  CMU01-16-1  3454719
#     Retest     Sample#  Cycles
# 37     0.0  CMU01-16-2  1079418
#     Retest     Sample#   Cycles
# 6      0.0  CMU01-17-1  10000000
# 38     0.0  CMU01-17-1  10000000
#     Retest     Sample#   Cycles
# 39     0.0  CMU01-17-2  10000000
# 40     1.0  CMU01-17-2    407372
#     Retest     Sample#   Cycles
# 41     0.0  CMU01-18-1  10000000
#     Retest     Sample#   Cycles
# 42     0.0  CMU01-18-2  10000000
#     Retest     Sample#   Cycles
# 43     0.0  CMU01-19-1  10000000
# 44     1.0  CMU01-19-1     20707
#     Retest     Sample#  Cycles
# 45     0.0  CMU01-19-2  2710226
#     Retest    Sample#   Cycles
# 46     0.0  CMU01-2-1  10000000
#     Retest    Sample#   Cycles
# 47     0.0  CMU01-2-2  10000000
#     Retest     Sample#   Cycles
# 48     0.0  CMU01-21-1  10000000
#     Retest     Sample#  Cycles
# 49     0.0  CMU01-21-2    64223
#     Retest     Sample#  Cycles
# 50     0.0  CMU01-22-1    72526
#     Retest     Sample#  Cycles
# 51     0.0  CMU01-22-2   470960
#     Retest     Sample#  Cycles
# 52     0.0  CMU01-23-1  6741725
#     Retest     Sample#  Cycles
# 53     0.0  CMU01-23-2   117170
#     Retest     Sample#  Cycles
# 54     0.0  CMU01-24-1    44004
#     Retest     Sample#  Cycles
# 55     0.0  CMU01-24-2  9287744
#     Retest     Sample#  Cycles
# 56     0.0  CMU01-25-1   447364
#     Retest     Sample#  Cycles
# 57     0.0  CMU01-25-2  2777424
#     Retest     Sample#   Cycles
# 60     0.0  CMU01-27-1  10000000
# 61     1.0  CMU01-27-1    120272
#     Retest     Sample#  Cycles
# 62     0.0  CMU01-27-2   148639
#     Retest     Sample#  Cycles
# 63     0.0  CMU01-28-1    49728
#     Retest     Sample#  Cycles
# 64     0.0  CMU01-28-2  4225323
#     Retest     Sample#  Cycles
# 65     0.0  CMU01-29-1   396155
#     Retest     Sample#  Cycles
# 66     0.0  CMU01-29-2    57191
#     Retest    Sample#  Cycles
# 0      0.0  CMU01-3-1  3763500
# 67     0.0  CMU01-3-1  3763500
#     Retest    Sample#  Cycles
# 1      0.0  CMU01-3-2  7335546
# 68     0.0  CMU01-3-2  7335546
#     Retest     Sample#   Cycles
# 69     0.0  CMU01-31-1  10000000
# 70     1.0  CMU01-31-1     18296
#     Retest     Sample#  Cycles
# 71     0.0  CMU01-31-2  6429346
#     Retest     Sample#  Cycles
# 72     0.0  CMU01-32-1    36609
#     Retest     Sample#  Cycles
# 73     0.0  CMU01-32-2   117757
#    Retest    Sample#   Cycles
# 0     0.0  CMU02-1-1  10000000
#    Retest    Sample#  Cycles
# 2     0.0  CMU02-2-1  1076227
#    Retest    Sample#   Cycles
# 3     0.0  CMU02-2-2  10000000
# 4     1.0  CMU02-2-2   8619694
#    Retest    Sample#  Cycles
# 5     0.0  CMU02-3-1   182343
#    Retest    Sample#  Cycles
# 6     0.0  CMU02-3-2  9317531
#    Retest    Sample#  Cycles
# 7     0.0  CMU02-4-1    39029
#    Retest    Sample#  Cycles
# 8     0.0  CMU02-4-2   113544
#     Retest    Sample#   Cycles
# 9      0.0  CMU02-5-1  10000000
# 10     1.0  CMU02-5-1  10000000
#     Retest    Sample#  Cycles
# 11     0.0  CMU02-5-2  6769073
#     Retest    Sample#  Cycles
# 12     0.0  CMU02-6-1    25505
#     Retest    Sample#  Cycles
# 13     0.0  CMU02-6-2    38884
#     Retest    Sample#  Cycles
# 14     0.0  CMU02-7-1  2240871
#     Retest    Sample#   Cycles
# 15     0.0  CMU02-7-2  10000000
# 16     1.0  CMU02-7-2   2902206
#     Retest    Sample#  Cycles
# 17     0.0  CMU02-8-1    96050
#     Retest    Sample#   Cycles
# 18     0.0  CMU02-8-2  10000000
# 19     1.0  CMU02-8-2    332193
#     Retest    Sample#  Cycles
# 20     0.0  CMU02-9-1  1388374
#     Retest    Sample#   Cycles
# 21     0.0  CMU02-9-2  10000000
#     Retest    Sample#  Cycles
# 22     0.0  CMU02-1-1  6436466
#     Retest    Sample#  Cycles
# 23     0.0  CMU02-1-2  3892306
#     Retest     Sample#  Cycles
# 24     0.0  CMU02-11-1  1040911
#     Retest     Sample#  Cycles
# 25     0.0  CMU02-11-2  6634332
#     Retest     Sample#  Cycles
# 26     0.0  CMU02-12-1  4534424
#     Retest     Sample#   Cycles
# 28     0.0  CMU02-13-1  10000000
#     Retest     Sample#  Cycles
# 29     0.0  CMU02-13-2    39133
#     Retest     Sample#  Cycles
# 30     0.0  CMU02-14-1  6770632
#     Retest     Sample#   Cycles
# 31     0.0  CMU02-14-2  10000000
#     Retest     Sample#  Cycles
# 33     0.0  CMU02-15-1  2881805
#     Retest     Sample#  Cycles
# 34     0.0  CMU02-15-2  5719303
#     Retest     Sample#   Cycles
# 35     0.0  CMU02-16-1  10000000
#     Retest     Sample#   Cycles
# 37     0.0  CMU02-17-1  10000000
#     Retest     Sample#  Cycles
# 39     0.0  CMU02-18-1   225261
#     Retest     Sample#   Cycles
# 40     0.0  CMU02-18-2  10000000
#     Retest     Sample#   Cycles
# 42     0.0  CMU02-19-1  10000000
# 43     1.0  CMU02-19-1  10000000
# 44     2.0  CMU02-19-1    385494
#     Retest     Sample#   Cycles
# 45     0.0  CMU02-19-2  10000000
# 46     1.0  CMU02-19-2    101270
#     Retest    Sample#   Cycles
# 47     0.0  CMU02-2-1  10000000
# 48     1.0  CMU02-2-1   2572055
#     Retest    Sample#  Cycles
# 49     0.0  CMU02-2-2  3416041
#     Retest     Sample#   Cycles
# 50     0.0  CMU02-21-1  10000000
# 51     1.0  CMU02-21-1  10000000
#     Retest     Sample#   Cycles
# 52     0.0  CMU02-21-2  10000000
#     Retest     Sample#  Cycles
# 53     0.0  CMU02-22-1  1962265
#     Retest     Sample#   Cycles
# 54     0.0  CMU02-22-2  10000000
# 55     1.0  CMU02-22-2   7741419
#     Retest     Sample#   Cycles
# 58     0.0  CMU02-24-1  10000000
# 59     1.0  CMU02-24-1  10000000
#     Retest     Sample#  Cycles
# 60     0.0  CMU02-24-2  1249761
#     Retest     Sample#  Cycles
# 61     0.0  CMU02-25-1  7061769
#     Retest     Sample#  Cycles
# 62     0.0  CMU02-25-2  7374765
#     Retest     Sample#  Cycles
# 63     0.0  CMU02-26-1   416147
#     Retest     Sample#  Cycles
# 64     0.0  CMU02-26-2   140777
#     Retest     Sample#  Cycles
# 65     0.0  CMU02-27-1  8766698
#     Retest     Sample#   Cycles
# 66     0.0  CMU02-27-2  10000000
#     Retest     Sample#   Cycles
# 67     0.0  CMU02-28-1  10000000
#     Retest     Sample#   Cycles
# 69     0.0  CMU02-29-1  10000000
# 70     1.0  CMU02-29-1   5074983
#     Retest    Sample#   Cycles
# 72     0.0  CMU02-3-1  10000000
#     Retest    Sample#   Cycles
# 73     0.0  CMU02-3-2  10000000
#     Retest     Sample#   Cycles
# 74     0.0  CMU02-31-1  10000000
# 75     1.0  CMU02-31-1    147361
#     Retest     Sample#  Cycles
# 76     0.0  CMU02-31-2   174030
#     Retest     Sample#   Cycles
# 77     0.0  CMU02-32-1  10000000
#     Retest     Sample#  Cycles
# 78     0.0  CMU02-32-2    33107
#    Retest    Sample#  Cycles
# 0     0.0  CMU03-1-1    19644
#    Retest    Sample#  Cycles
# 1     0.0  CMU03-1-2    30027
#    Retest    Sample#  Cycles
# 2     0.0  CMU03-2-1    20671
#    Retest    Sample#  Cycles
# 3     0.0  CMU03-2-2    85829
#    Retest    Sample#   Cycles
# 6     0.0  CMU03-4-1  10000000
#    Retest    Sample#  Cycles
# 7     0.0  CMU03-4-2   215574
#    Retest    Sample#   Cycles
# 8     0.0  CMU03-5-1  10000000
# 9     1.0  CMU03-5-1     42335
#     Retest    Sample#  Cycles
# 10     0.0  CMU03-5-2  2119591
#     Retest    Sample#  Cycles
# 11     0.0  CMU03-6-1    67800
#     Retest    Sample#  Cycles
# 12     0.0  CMU03-6-2  8758948
#     Retest    Sample#   Cycles
# 15     0.0  CMU03-8-1  10000000
# 16     1.0  CMU03-8-1     51526
#     Retest    Sample#   Cycles
# 17     0.0  CMU03-8-2  10000000
# 18     1.0  CMU03-8-2     18007
#     Retest    Sample#  Cycles
# 19     0.0  CMU03-9-1  3006164
#     Retest    Sample#   Cycles
# 20     0.0  CMU03-9-2  10000000
# 21     1.0  CMU03-9-2    764529
#     Retest    Sample#   Cycles
# 22     0.0  CMU03-1-1  10000000
# 23     1.0  CMU03-1-1     89454
#     Retest    Sample#  Cycles
# 24     0.0  CMU03-1-2    36817
#     Retest     Sample#  Cycles
# 27     0.0  CMU03-12-1   239612
#     Retest     Sample#   Cycles
# 28     0.0  CMU03-12-2  10000000
# 29     1.0  CMU03-12-2   7041493
#     Retest     Sample#  Cycles
# 30     0.0  CMU03-13-1  1494947
#     Retest     Sample#  Cycles
# 31     0.0  CMU03-13-2   104435
#     Retest     Sample#   Cycles
# 32     0.0  CMU03-14-1  10000000
# 33     1.0  CMU03-14-1     87420
#     Retest     Sample#  Cycles
# 34     0.0  CMU03-14-2   251943
#     Retest     Sample#   Cycles
# 35     0.0  CMU03-15-1  10000000
#     Retest     Sample#  Cycles
# 36     0.0  CMU03-15-2    31600
#     Retest     Sample#   Cycles
# 37     0.0  CMU03-16-1  10000000
#     Retest     Sample#  Cycles
# 38     0.0  CMU03-16-2    51758
#     Retest     Sample#  Cycles
# 39     0.0  CMU03-17-1    47486
#     Retest     Sample#  Cycles
# 40     0.0  CMU03-17-2  4170839
#     Retest     Sample#  Cycles
# 41     0.0  CMU03-18-1    48456
#     Retest     Sample#  Cycles
# 42     0.0  CMU03-18-2   441584
#     Retest     Sample#  Cycles
# 43     0.0  CMU03-19-1   154229
#     Retest     Sample#  Cycles
# 44     0.0  CMU03-19-2   211182
#     Retest    Sample#  Cycles
# 45     0.0  CMU03-2-1   355087
#     Retest    Sample#  Cycles
# 46     0.0  CMU03-2-2  6401621
#     Retest     Sample#  Cycles
# 47     0.0  CMU03-21-1    51771
#     Retest     Sample#  Cycles
# 48     0.0  CMU03-21-2   183705
#     Retest     Sample#   Cycles
# 49     0.0  CMU03-22-1  10000000
# 50     1.0  CMU03-22-1  10000000
#     Retest     Sample#  Cycles
# 51     0.0  CMU03-22-2   212803
#     Retest     Sample#  Cycles
# 52     0.0  CMU03-23-1  9014278
#     Retest     Sample#  Cycles
# 53     0.0  CMU03-23-2   112552
#     Retest     Sample#  Cycles
# 56     0.0  CMU03-25-1   346301
#     Retest     Sample#   Cycles
# 57     0.0  CMU03-25-2  10000000
# 58     1.0  CMU03-25-2  10000000
# 59     2.0  CMU03-25-2     23399
#     Retest     Sample#   Cycles
# 60     0.0  CMU03-26-1  10000000
#     Retest     Sample#  Cycles
# 61     0.0  CMU03-26-2    96076
#     Retest     Sample#   Cycles
# 64     0.0  CMU03-28-1  10000000
#     Retest     Sample#   Cycles
# 65     0.0  CMU03-28-2  10000000
#     Retest     Sample#   Cycles
# 66     0.0  CMU03-29-1  10000000
#     Retest     Sample#  Cycles
# 67     0.0  CMU03-29-2  1330430
#     Retest    Sample#  Cycles
# 68     0.0  CMU03-3-1    25423
#     Retest    Sample#  Cycles
# 69     0.0  CMU03-3-2    60266
#     Retest     Sample#  Cycles
# 70     0.0  CMU03-31-1    88284
#     Retest     Sample#   Cycles
# 71     0.0  CMU03-31-2  10000000
# 72     1.0  CMU03-31-2    125250
#     Retest     Sample#   Cycles
# 73     0.0  CMU03-32-1  10000000
#     Retest     Sample#   Cycles
# 74     0.0  CMU03-32-2  10000000
#    Retest    Sample#  Cycles
# 0     0.0  CMU05-1-1   184479
#    Retest    Sample#  Cycles
# 1     0.0  CMU05-1-2   112950
#    Retest    Sample#  Cycles
# 4     0.0  CMU05-3-1  2911882
#    Retest    Sample#  Cycles
# 5     0.0  CMU05-3-2  6761610
#     Retest    Sample#  Cycles
# 10     0.0  CMU05-6-1     4664
#     Retest    Sample#  Cycles
# 11     0.0  CMU05-6-2   189888
#     Retest    Sample#  Cycles
# 16     0.0  CMU05-9-1    51791
#     Retest    Sample#  Cycles
# 17     0.0  CMU05-9-2    58626
#     Retest     Sample#   Cycles
# 20     0.0  CMU05-11-1  10000000
# 21     1.0  CMU05-11-1    226550
#     Retest     Sample#  Cycles
# 22     0.0  CMU05-11-2    86201
#     Retest     Sample#  Cycles
# 23     0.0  CMU05-12-1    44220
#     Retest     Sample#  Cycles
# 24     0.0  CMU05-12-2    99468
#     Retest     Sample#  Cycles
# 35     0.0  CMU05-18-1   135179
#     Retest     Sample#   Cycles
# 36     0.0  CMU05-18-2  10000000
# 37     1.0  CMU05-18-2     29486
#     Retest     Sample#   Cycles
# 38     0.0  CMU05-19-1  10000000
#     Retest     Sample#  Cycles
# 39     0.0  CMU05-19-2    18101
#     Retest    Sample#  Cycles
# 40     0.0  CMU05-2-1   332106
#     Retest     Sample#  Cycles
# 48     0.0  CMU05-24-1   467663
#     Retest     Sample#  Cycles
# 49     0.0  CMU05-24-2   521691
#     Retest     Sample#  Cycles
# 50     0.0  CMU05-25-1    33339
#     Retest     Sample#  Cycles
# 51     0.0  CMU05-25-2    96000
#     Retest     Sample#  Cycles
# 58     0.0  CMU05-29-1    51409
#     Retest     Sample#  Cycles
# 59     0.0  CMU05-29-2  3515761
#    Retest    Sample#   Cycles
# 0     0.0  CMU14-1-1  10000000
#    Retest    Sample#  Cycles
# 1     0.0  CMU14-1-2    46258
#    Retest    Sample#  Cycles
# 2     0.0  CMU14-2-1    19833
#    Retest    Sample#  Cycles
# 3     0.0  CMU14-2-2    23363
#    Retest    Sample#   Cycles
# 4     0.0  CMU14-3-1  10000000
#    Retest    Sample#   Cycles
# 5     0.0  CMU14-3-2  10000000
#    Retest    Sample#  Cycles
# 6     0.0  CMU14-4-1    30058
#    Retest    Sample#  Cycles
# 7     0.0  CMU14-4-2   268539
#    Retest    Sample#  Cycles
# 8     0.0  CMU14-5-1    19505
#    Retest    Sample#  Cycles
# 9     0.0  CMU14-5-2  1854774
#     Retest    Sample#   Cycles
# 10     0.0  CMU14-6-1  10000000
#     Retest    Sample#   Cycles
# 11     0.0  CMU14-6-2  10000000
#     Retest    Sample#  Cycles
# 12     0.0  CMU14-7-1    68366
#     Retest    Sample#   Cycles
# 13     0.0  CMU14-7-2  10000000
#     Retest    Sample#  Cycles
# 16     0.0  CMU14-9-1    64428
#     Retest    Sample#   Cycles
# 17     0.0  CMU14-9-2  10000000
#     Retest    Sample#  Cycles
# 18     0.0  CMU14-1-1  6185730
#     Retest     Sample#  Cycles
# 20     0.0  CMU14-11-1    27306
#     Retest     Sample#   Cycles
# 21     0.0  CMU14-11-2  10000000
#     Retest     Sample#  Cycles
# 22     0.0  CMU14-12-1    75080
#     Retest     Sample#  Cycles
# 23     0.0  CMU14-12-2    57131
#     Retest     Sample#  Cycles
# 24     0.0  CMU14-13-1    56000
#     Retest     Sample#   Cycles
# 25     0.0  CMU14-13-2  10000000
#     Retest     Sample#  Cycles
# 26     0.0  CMU14-14-1  3007772
#     Retest     Sample#  Cycles
# 27     0.0  CMU14-14-2   126205
#     Retest     Sample#  Cycles
# 32     0.0  CMU14-17-1    17192
#     Retest     Sample#  Cycles
# 33     0.0  CMU14-17-2    22934
#     Retest     Sample#   Cycles
# 34     0.0  CMU14-18-1  10000000
#     Retest     Sample#   Cycles
# 36     0.0  CMU14-19-1  10000000
#     Retest    Sample#  Cycles
# 38     0.0  CMU14-2-1    63071
#     Retest    Sample#  Cycles
# 39     0.0  CMU14-2-2   107975
#     Retest     Sample#   Cycles
# 40     0.0  CMU14-21-1  10000000
#     Retest     Sample#  Cycles
# 42     0.0  CMU14-22-1   928631
#     Retest     Sample#  Cycles
# 43     0.0  CMU14-22-2  3091730
#     Retest     Sample#   Cycles
# 50     0.0  CMU14-26-1  10000000
#     Retest     Sample#  Cycles
# 51     0.0  CMU14-26-2    93992
#     Retest     Sample#   Cycles
# 54     0.0  CMU14-28-1  10000000
#     Retest     Sample#  Cycles
# 2      0.0  CMU14-29-1   117937
# 56     0.0  CMU14-29-1   117937
#    Retest    Sample#  Cycles
# 0     0.0  CMU15-1-1    23472
#    Retest    Sample#  Cycles
# 1     0.0  CMU15-1-2   130897
#    Retest    Sample#  Cycles
# 2     0.0  CMU15-2-1   588148
#    Retest    Sample#  Cycles
# 3     0.0  CMU15-2-2   279520
#    Retest    Sample#  Cycles
# 4     0.0  CMU15-3-1  4282701
#    Retest    Sample#   Cycles
# 5     0.0  CMU15-3-2  10000000
#    Retest    Sample#  Cycles
# 6     0.0  CMU15-4-1   462796
#    Retest    Sample#  Cycles
# 7     0.0  CMU15-4-2  2124883
#    Retest    Sample#  Cycles
# 8     0.0  CMU15-5-1    17534
#    Retest    Sample#   Cycles
# 9     0.0  CMU15-5-2  10000000
#     Retest    Sample#  Cycles
# 12     0.0  CMU15-7-1    24645
#     Retest    Sample#  Cycles
# 13     0.0  CMU15-7-2   198681
#     Retest    Sample#  Cycles
# 14     0.0  CMU15-8-1    38402
#     Retest    Sample#   Cycles
# 15     0.0  CMU15-8-2  10000000
#     Retest    Sample#  Cycles
# 16     0.0  CMU15-9-1  4320425
#     Retest    Sample#   Cycles
# 17     0.0  CMU15-9-2  10000000
#     Retest     Sample#  Cycles
# 20     0.0  CMU15-11-1   212325
#     Retest     Sample#   Cycles
# 21     0.0  CMU15-11-2  10000000
#     Retest     Sample#  Cycles
# 28     0.0  CMU15-15-1  1682670
#     Retest     Sample#   Cycles
# 29     0.0  CMU15-15-2  10000000
#     Retest     Sample#  Cycles
# 30     0.0  CMU15-16-1   225496
#     Retest     Sample#  Cycles
# 31     0.0  CMU15-16-2  4436185
#     Retest     Sample#  Cycles
# 40     0.0  CMU15-21-1    38343
#     Retest     Sample#   Cycles
# 41     0.0  CMU15-21-2  10000000
#     Retest     Sample#   Cycles
# 42     0.0  CMU15-22-1  10000000
#     Retest     Sample#   Cycles
# 44     0.0  CMU15-23-1  10000000
#     Retest     Sample#  Cycles
# 45     0.0  CMU15-23-2    48668
#     Retest     Sample#  Cycles
# 46     0.0  CMU15-24-1  1886895
#     Retest     Sample#  Cycles
# 47     0.0  CMU15-24-2  9656072
#     Retest     Sample#  Cycles
# 50     0.0  CMU15-26-1   110664
#     Retest     Sample#  Cycles
# 51     0.0  CMU15-26-2  6386591
#     Retest     Sample#   Cycles
# 60     0.0  CMU15-31-1  10000000
#     Retest     Sample#   Cycles
# 61     0.0  CMU15-31-2  10000000
#    Retest       Sample#  Cycles
# 9     0.0  NASA01-V31-1    77257
#     Retest       Sample#  Cycles
# 10     0.0  NASA01-V31-2   313124
#     Retest       Sample#   Cycles
# 11     0.0  NASA01-V31-3  10000000
#     Retest       Sample#   Cycles
# 12     0.0  NASA01-V32-1  10000000
#     Retest       Sample#  Cycles
# 16     0.0  NASA01-V34-1    80551
#     Retest       Sample#  Cycles
# 17     0.0  NASA01-V34-2   301436
#     Retest       Sample#  Cycles
# 18     0.0  NASA01-V34-3   230179
#     Retest       Sample#  Cycles
# 21     0.0  NASA01-V42-1    36732
#     Retest       Sample#  Cycles
# 23     0.0  NASA01-V43-1    96897
#     Retest       Sample#  Cycles
# 24     0.0  NASA01-V43-2    91602
#     Retest       Sample#   Cycles
# 25     0.0  NASA01-V43-3  10000000
#     Retest       Sample#   Cycles
# 26     0.0  NASA01-V44-1  10000000
#     Retest       Sample#  Cycles
# 27     0.0  NASA01-V44-2  9088560
#     Retest       Sample#  Cycles
# 28     0.0  NASA01-V44-3   128519
#     Retest       Sample#  Cycles
# 31     0.0  NASA01-V52-1   154759
#     Retest       Sample#  Cycles
# 33     0.0  NASA01-V53-1   191500
#     Retest       Sample#  Cycles
# 34     0.0  NASA01-V53-2   590296
#     Retest       Sample#  Cycles
# 35     0.0  NASA01-V54-1    67733
#     Retest       Sample#  Cycles
# 36     0.0  NASA01-V54-2   293777
#     Retest       Sample#   Cycles
# 37     0.0  NASA01-V54-3  10000000
# 38     1.0  NASA01-V54-3     84968
#     Retest       Sample#  Cycles
# 39     0.0  NASA01-V61-1    29665
#     Retest       Sample#  Cycles
# 40     0.0  NASA01-V61-2    24474
#     Retest       Sample#   Cycles
# 45     0.0  NASA01-V64-1  10000000
#     Retest       Sample#   Cycles
# 46     0.0  NASA01-V64-2  10000000
#     Retest       Sample#  Cycles
# 49     0.0  NASA01-V72-1   345452
#     Retest       Sample#  Cycles
# 53     0.0  NASA01-V74-1   168405
#     Retest       Sample#   Cycles
# 54     0.0  NASA01-V74-2  10000000
#     Retest       Sample#  Cycles
# 55     0.0  NASA01-V74-3   174741
#     Retest       Sample#  Cycles
# 58     0.0  NASA01-V82-1   118081
#     Retest       Sample#  Cycles
# 62     0.0  NASA01-V83-3    13398
#     Retest       Sample#  Cycles
# 63     0.0  NASA01-V84-1    85018
#     Retest       Sample#  Cycles
# 64     0.0  NASA01-V84-2   265025
#     Retest       Sample#  Cycles
# 67     0.0  NASA01-V92-1   151536
#     Retest       Sample#  Cycles
# 69     0.0  NASA01-V93-1   145254
#    Retest       Sample#   Cycles
# 0     0.0  NASA01-VE1-1  10000000
#    Retest       Sample#   Cycles
# 1     0.0  NASA01-VE1-2  10000000
#    Retest       Sample#  Cycles
# 2     0.0  NASA01-VE2-1    53650
#    Retest       Sample#   Cycles
# 6     0.0  NASA01-VE4-1  10000000
# 7     1.0  NASA01-VE4-1  10000000
#    Retest       Sample#  Cycles
# 8     0.0  NASA01-VE4-2  4000000

# %% [markdown]
# Scrolling through the above code makes it seem like Sample# is sufficent to have almost all of the groups with retakes to have at least 1 other sample.

# %%
for name, group in excel_df.groupby(['Sample#']):
    group

# %% [markdown]
# ## FAIRify Column names
# I would like to have the stitched image(stitched or STITCHED), the initiation site(001), the manuel masks for both
# We might want to consider the number of runouts in process parameters
# We already have classified images, so it might be good to have a CNN, can be used to establish the conditions
# We might want to consider the
# See if the centroid of the defects for x and y is within the bounding box of the sample

# %%
#Make datasets from the dataframe
# from make_dataset import dataset_setup
# dataset_setup(, supervised_masks, TRAIN_SPLIT, VAL_SPLIT, TEST_SPLIT, combined_dataset = False, BATCH_SIZE=5)

# %% [markdown]
# ## Image Filepaths -> Dictionary Keys

# %%
import os
fractography_path = '/mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractography'
manuel_mask_path = '/mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/keyence-fractography/manuel_mask'
#Adds File if Condition(path) return True
def recursive_search(condition,path:str, file_list:list):
    if os.path.isdir(path):
        for path_loop in os.listdir(path):
            recursive_search(condition,os.path.join(path,path_loop),file_list)
    else:
        if(condition(path)):
            file_list.append(path)
    return file_list

#Definition Different columns that would be valuable to have
def stitched(path):
    if 'stitched' in path.lower():
        return True
    elif'composite' in path.lower():
        return True
    else:
        return False

def exists(path):
    return True 
def png(path):
    if ('.png' in path.lower()):
        return True
    else:
        return False
def marked(path):
    if 'marked' in path.lower():
        return True
    else:
        return False

def initiation(path):
    if '_001' in path:
        return True
    elif 'initiation' in path.lower():
        return True
    else:
        return False
def marked_and_initiation(path):
    if initiation(path) and marked(path):
        return True
    else:
        return False
def marked_and_stitched(path):
    if marked(path) and stitched(path):
        return True
    else:
        return False
def fatigue(path):
    if 'fatigue' in path.lower():
        return True
    else:
        return False
def overload(path):
    if 'overload' in path.lower():
        return True
    else:
        return False
def fatigue_and_png(path):
    if png(path) and fatigue(path):
        return True
    else:
        return False
def stitched_and_png_not_fatigue(path):
    if png(path) and stitched(path) and not fatigue(path):
        return True
    else:
        return False
path_list = [fractography_path,manuel_mask_path]
condition_list = [exists,stitched_and_png_not_fatigue,initiation,marked_and_initiation, marked_and_stitched,fatigue,overload,fatigue_and_png]
name = []
column_dict = {}
i=0
for top_folder in path_list:
    for column in condition_list:
        temp_list = []
        column_dict[column.__name__+'_'+os.path.basename(top_folder)]=recursive_search(
            column,
            top_folder,
            temp_list
        )
        name.append((column.__name__+'_'+os.path.basename(top_folder),len(column_dict[column.__name__+'_'+os.path.basename(top_folder)])))
        print(str(name[i]) +f'\tPosition: {i}')
        i+=1
# Out:
# ('exists_fractography', 5256)	Position: 0
# ('stitched_and_png_not_fatigue_fractography', 27)	Position: 1
# ('initiation_fractography', 768)	Position: 2
# ('marked_and_initiation_fractography', 51)	Position: 3
# ('marked_and_stitched_fractography', 52)	Position: 4
# ('fatigue_fractography', 0)	Position: 5
# ('overload_fractography', 2)	Position: 6
# ('fatigue_and_png_fractography', 0)	Position: 7
# ('exists_manuel_mask', 397)	Position: 8
# ('stitched_and_png_not_fatigue_manuel_mask', 164)	Position: 9
# ('initiation_manuel_mask', 0)	Position: 10
# ('marked_and_initiation_manuel_mask', 0)	Position: 11
# ('marked_and_stitched_manuel_mask', 3)	Position: 12
# ('fatigue_manuel_mask', 112)	Position: 13
# ('overload_manuel_mask', 112)	Position: 14
# ('fatigue_and_png_manuel_mask', 56)	Position: 15

# %% [markdown]
# ## Dictionary Keys -> Pandas DataFrames
# Now that we have the paths in a python dictionary, we can convert each key into a a different dataframe, with type and series information available to merge the data frames on.
# Here, the regex package is used to identiy the common file name structure.

# %%
import re
check = re.compile(r'''
    ^(EP|NASA|CMU)  # Start with EP, NASA, or CMU (case insensitive)
    [-_]?           # Optional separator
    (\d+|O\d+)      # Number or O followed by number
    .*?             # Any characters in between (non-greedy)
    (?:             # Non-capturing group
        [-_]?V?     # Optional separator and V
        ([E\d]+)       # Version number
        (?:[-_](\d+))?  # Optional additional number
    )?
    .*?             # Any characters in between (non-greedy)
    \.(png|tif)$    # File extension (png or tif)
''', re.VERBOSE | re.IGNORECASE)
def output(pattern):
    match = re.search(check,pattern)
    if(match):
        # print(match.groups())
        # print(match)
        return match.group(1).lower()+match.group(2), match.group(3).lower() ,match.group(4) if match.group(4) else None
    else:
        return None

#Testing Function on Data
# for key in column_dict:
#     for field in column_dict[key]:
#         if not output(field.split('/')[-1]):
#             print(field.split('/')[-1])

            
dataframe_list = []
for i, key in enumerate(column_dict):
    type_column = []
    series_column = []
    posit_idx_column = []
    basename = []
    Sample_num = []
    for j, field in enumerate(column_dict[key]):
        if output(field.split('/')[-1]):
            type_inst, series_inst, posit_idx_inst = output(field.split('/')[-1])
            type_column.append(type_inst)
            series_column.append(series_inst)
            posit_idx_column.append(posit_idx_inst)
            basename.append(field.split('/')[-1])
            if posit_idx_inst == None:
                Sample_num.append(type_inst.upper()+'-'+str(series_inst)+'-1')
            else:
                Sample_num.append(type_inst.upper()+'-'+str(series_inst)+'-'+str(posit_idx_inst))
        else:
            type_inst=None
            series_inst=None
            posit_idx_inst=None
    path_column = pd.Series(column_dict[key],name='path')
    type_column = pd.Series(type_column, name='type')
    series_column = pd.Series(series_column,name='series')
    posit_idx_column = pd.Series(posit_idx_column,name='posit_idx')
    basename_column = pd.Series(basename,name='basename')
    Sample_num_column= pd.Series(Sample_num, name = 'Sample#')
    dataframe_list.append(
        pd.concat(
            [
                Sample_num_column,
                path_column,
                type_column,
                series_column,
                posit_idx_column,
                basename_column,
            ],
            axis=1
        )
    )
    print(str(name[i])+ '\tPosition: '+str(i))
    print(dataframe_list[i].head(7))
    print(dataframe_list[i].columns)
# Out:
# ('exists_fractography', 5256)	Position: 0
#      Sample#                                               path   type series  \
# 0  CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
# 1  CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
# 2  CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
# 3  CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
# 4  CMU01-1-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
# 5  CMU01-1-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
# 6  CMU01-1-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01      1
#
#   posit_idx                                 basename
# 0         1  CMU01-1-1 INITIATION_001-checkpoint.tif
# 1         1             CMU01-1-1 INITIATION_001.tif
# 2         1             CMU01-1-1 INITIATION_002.tif
# 3         1                   CMU01-1-1 STITCHED.tif
# 4         2             CMU01-1-2 INITIATION_001.tif
# 5         2                   CMU01-1-2 STITCHED.tif
# 6         2                        CMU01-1-2_001.tif
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('stitched_and_png_not_fatigue_fractography', 27)	Position: 1
#      Sample#                                               path  type series  \
# 0  EP04-84-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep04     84
# 1  EP05-44-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     44
# 2  EP05-44-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     44
# 3  EP05-53-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     53
# 4  EP05-53-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     53
# 5  EP05-63-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     63
# 6  EP05-74-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     74
#
#   posit_idx                        basename
# 0      None  EP04-V84-FullComposite.png.tif
# 1         1         EP05-V44-1-stitched.png
# 2         2         EP05-V44-2-stitched.png
# 3         1         EP05-V53-1-stitched.png
# 4         2         EP05-V53-2-stitched.png
# 5         2         EP05-V63-2-stitched.png
# 6         1         EP05-V74-1-stitched.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('initiation_fractography', 768)	Position: 2
#       Sample#                                               path   type  \
# 0   CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
# 1   CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
# 2   CMU01-1-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
# 3   CMU01-1-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
# 4   CMU01-1-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
# 5  CMU01-10-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
# 6  CMU01-10-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  cmu01
#
#   series posit_idx                                 basename
# 0      1         1  CMU01-1-1 INITIATION_001-checkpoint.tif
# 1      1         1             CMU01-1-1 INITIATION_001.tif
# 2      1         1             CMU01-1-1 INITIATION_002.tif
# 3      1         2             CMU01-1-2 INITIATION_001.tif
# 4      1         2                        CMU01-1-2_001.tif
# 5     10         1                       CMU01-10-1_001.tif
# 6     10         2                       CMU01-10-2_001.tif
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('marked_and_initiation_fractography', 51)	Position: 3
#      Sample#                                               path  type series  \
# 0  EP05-83-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     83
# 1  EP07-33-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep07     33
# 2  EP07-33-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep07     33
# 3  EP07-71-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep07     71
# 4  EP07-71-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep07     71
# 5  EP07-72-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep07     72
# 6  EP07-72-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep07     72
#
#   posit_idx                                  basename
# 0         2  EP05-V83-2-stitched-InitiationMarked.tif
# 1         1                 EP07_V33-1_001-Marked.tif
# 2         2                 EP07_V33-2_001_marked.tif
# 3         1                 EP07-V71-1_001-Marked.tif
# 4         2                 EP07-V71-2_001-Marked.tif
# 5         1                 EP07_V72-1_001_marked.tif
# 6         2                 EP07_V72-2_001_marked.tif
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('marked_and_stitched_fractography', 52)	Position: 4
#      Sample#                                               path  type series  \
# 0  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep04     21
# 1  EP04-23-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep04     23
# 2  EP05-31-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     31
# 3  EP05-44-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     44
# 4  EP05-53-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     53
# 5  EP05-74-1  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     74
# 6  EP05-74-2  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  ep05     74
#
#   posit_idx                           basename
# 0      None  EP04-V21-FullComposite-Marked.tif
# 1      None  EP04-V23-FullComposite-Marked.tif
# 2         2     EP05-V31-2-STITCHED-Marked.tif
# 3         1     EP05-V44-1-stitched_MARKED.tif
# 4         1     EP05-V53-1-stitched-MARKED.tif
# 5         1     EP05-V74-1-stitched-MARKED.tif
# 6         2     EP05-V74-2-stitched-MARKED.tif
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('fatigue_fractography', 0)	Position: 5
# Empty DataFrame
# Columns: [Sample#, path, type, series, posit_idx, basename]
# Index: []
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('overload_fractography', 2)	Position: 6
#   Sample#                                               path type series  \
# 0     NaN  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  NaN    NaN
# 1     NaN  /mnt/vstor/CSE_MSE_RXF131/staging/mds3/fractog...  NaN    NaN
#
#   posit_idx basename
# 0       NaN      NaN
# 1       NaN      NaN
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('fatigue_and_png_fractography', 0)	Position: 7
# Empty DataFrame
# Columns: [Sample#, path, type, series, posit_idx, basename]
# Index: []
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('exists_manuel_mask', 397)	Position: 8
#      Sample#                                               path  type series  \
# 0  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 1  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 2  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 3  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 4  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 5  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 6  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
#
#   posit_idx                              basename
# 0      None         EP04-V21-stitched-fatigue.png
# 1      None         EP04-V21-stitched-fatigue.tif
# 2      None        EP04-V21-stitched-overload.png
# 3      None        EP04-V21-stitched-overload.tif
# 4      None                 EP04V21-Composite.png
# 5      None                 EP04V21-Composite.tif
# 6      None  EP04V21-Composite_post_processed.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('stitched_and_png_not_fatigue_manuel_mask', 164)	Position: 9
#      Sample#                                               path  type series  \
# 0  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 1  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 2  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 3  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 4  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 5  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 6  EP04-62-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     62
#
#   posit_idx                               basename
# 0      None         EP04-V21-stitched-overload.png
# 1      None                  EP04V21-Composite.png
# 2      None   EP04V21-Composite_post_processed.png
# 3      None                 EP04-V24-Composite.png
# 4      None  EP04-V24-Composite_post_processed.png
# 5      None         EP04-V24-stitched-overload.png
# 6      None                 EP04-V62-Composite.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('initiation_manuel_mask', 0)	Position: 10
# Empty DataFrame
# Columns: [Sample#, path, type, series, posit_idx, basename]
# Index: []
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('marked_and_initiation_manuel_mask', 0)	Position: 11
# Empty DataFrame
# Columns: [Sample#, path, type, series, posit_idx, basename]
# Index: []
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('marked_and_stitched_manuel_mask', 3)	Position: 12
#      Sample#                                               path  type series  \
# 0  EP05-44-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep05     44
# 1  EP05-44-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep05     44
# 2  EP05-44-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep05     44
#
#   posit_idx                                       basename
# 0         1                 EP05-V44-1-stitched_MARKED.png
# 1         1                 EP05-V44-1-stitched_MARKED.tif
# 2         1  EP05-V44-1-stitched_MARKED_post_processed.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('fatigue_manuel_mask', 112)	Position: 13
#      Sample#                                               path  type series  \
# 0  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 1  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 2  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 3  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 4  EP04-62-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     62
# 5  EP04-62-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     62
# 6  EP04-65-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     65
#
#   posit_idx                       basename
# 0      None  EP04-V21-stitched-fatigue.png
# 1      None  EP04-V21-stitched-fatigue.tif
# 2      None  EP04-V24-stitched-fatigue.png
# 3      None  EP04-V24-stitched-fatigue.tif
# 4      None  EP04-V62-stitched-fatigue.png
# 5      None  EP04-V62-stitched-fatigue.tif
# 6      None  EP04-V65-stitched-fatigue.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('overload_manuel_mask', 112)	Position: 14
#      Sample#                                               path  type series  \
# 0  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 1  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 2  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 3  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 4  EP04-62-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     62
# 5  EP04-62-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     62
# 6  EP04-65-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     65
#
#   posit_idx                        basename
# 0      None  EP04-V21-stitched-overload.png
# 1      None  EP04-V21-stitched-overload.tif
# 2      None  EP04-V24-stitched-overload.png
# 3      None  EP04-V24-stitched-overload.tif
# 4      None  EP04-V62-stitched-overload.png
# 5      None  EP04-V62-stitched-overload.tif
# 6      None  EP04-V65-stitched-overload.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# ('fatigue_and_png_manuel_mask', 56)	Position: 15
#      Sample#                                               path  type series  \
# 0  EP04-21-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     21
# 1  EP04-24-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     24
# 2  EP04-62-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     62
# 3  EP04-65-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     65
# 4  EP04-66-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     66
# 5  EP04-68-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     68
# 6  EP04-81-1  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/key...  ep04     81
#
#   posit_idx                       basename
# 0      None  EP04-V21-stitched-fatigue.png
# 1      None  EP04-V24-stitched-fatigue.png
# 2      None  EP04-V62-stitched-fatigue.png
# 3      None  EP04-V65-stitched-fatigue.png
# 4      None  EP04-V66-stitched-fatigue.png
# 5      None  EP04-V68-stitched-fatigue.png
# 6      None  EP04-V81-stitched-fatigue.png
# Index(['Sample#', 'path', 'type', 'series', 'posit_idx', 'basename'], dtype='object')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Now that we have build ID in all of the dataframes for the both Brett's dataframe, and the images, we can merge them and try to correlate the variation of the testing and processing conditions with some properties of the defects contained in the images.

# %%
import psutil
columns_to_keep = ['Sample#','path']
combined_df = pd.merge(dataframe_list[0][columns_to_keep],dataframe_list[1][columns_to_keep],on='Sample#',suffixes=('_x'+name[0][0],'_'+name[1][0]),how='outer')
i=0
for dataframe in dataframe_list:
    try:
        combined_df = pd.merge(combined_df,dataframe[columns_to_keep],on='Sample#',suffixes=('',f'_{name[i][0]}'),how='outer')
        dataframe.to_csv(f'{i}.csv')
        i+=1
    except Exception as e:
        print(e)
combined_df.to_csv('combined_df_temp.csv')
excel_df.to_csv('excel_df_temp.csv')
combined_df = pd.merge(combined_df,excel_df,on='Sample#')
combined_df.to_csv('combined_df.csv')
row_structure = '|{:^50}|{:^10}|{:^20}|'
print(row_structure.format('Column name', 'Nulls','Position'))
i=0
for column in combined_df.columns:
    print(row_structure.format(column, str(combined_df[column].isna().sum()),str(i)))
    i+=1

# %% [markdown]
# Now that we have the files in a dataframe, we can match their titles to processing paramters.

# %%
for i in range(len(dataframe_list)):
    dataframe_list[i]['Power (W)'] = dataframe_list[i].apply(lambda row:name_to_power(row,6))
output['Power (W)'] = output['Sample#'].apply(lambda row:name_to_power(row,6))
output['Velocity (mm/s)'] = output['Sample#'].apply(lambda row: name_to_velocity(row,6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/job.2069900.hpc/ipykernel_2624605/3198571135.py in ?()
#       1 for i in range(len(dataframe_list)):
# ----> 2     dataframe_list[i]['Power (W)'] = dataframe_list[i].apply(lambda row:name_to_power(row,6))
#       3 output['Power (W)'] = output['Sample#'].apply(lambda row:name_to_power(row,6))
#       4 output['Velocity (mm/s)'] = output['Sample#'].apply(lambda row: name_to_velocity(row,6))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in ?(self, key, value)
#    4285             self._setitem_frame(key, value)
#    4286         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4287             self._setitem_array(key, value)
#    4288         elif isinstance(value, DataFrame):
# -> 4289             self._set_item_frame_value(key, value)
#    4290         elif (
#    4291             is_list_like(value)
#    4292             and not self.columns.is_unique
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in ?(self, key, value)
#    4443
#    4444             return self.isetitem(locs, value)
#    4445
#    4446         if len(value.columns) > 1:
# -> 4447             raise ValueError(
#    4448                 "Cannot set a DataFrame with multiple columns to the single "
#    4449                 f"column {key}"
#    4450             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column Power (W)

# %% [markdown]
# # Train Model on Defects
# Now that we have dataframes, we can begin to train the models by merging them. The easiest region of interest is the fatigue region, so we will begin with that. Histogram matching will be applied to help increase contrast

# %%
# from unet import Unet
# import importlib
# import cv2
# from train_GAN import train_GAN
# from discriminator_loss import discriminator_loss
# from semi_supervised_loss import semi_supervised_loss
# from multiclass_dataset import Multiclass_dataset
# from combined_dataset import combined_dataset
# #importlib.reload(make_dataset)
# from make_dataset import dataset_setup
# import torch
# # Initalize The Dataset
# merge = pd.merge(dataframe_list[-1],dataframe_list[9],on=['type','series','posit_idx'],suffixes=['_mask','_stitched'])
# print(len(merge))
# print(len(dataframe_list[-1]))
# # for i in range(len(merge)):
# #     print(merge['basename_stitched'][i]+str(merge['posit_idx'][i]) +'\t'+str(merge['series'][i])+'\t'+str(merge['type'][i]))
# disunion = dataframe_list[9]['path']
# train_dl, valid_dl = dataset_setup(
#     [merge['path_stitched']],
#     [merge['path_mask']],
#     .80,
#     .15,
#     .05,
# )
# def size_transform(size:[int]):
#     if len(size)!=2:
#         raise ValueError('The size must a list of 2 integers')
#     def apply_transform(Image):
#         return cv2.resize(image,size)

# resize_func = size_transform([512,512])
# unsegmented_raw = Multiclass_dataset(x_unsup=[disunion.dropna()],transform=resize_func)
# # x_unsup is the 
# segmentor = Unet(
#     input_channels = 1,
#     output_channels=1,
# ).to('cuda:0')
# discriminator = Unet(
#     input_channels = 1,
#     output_channels =1,
# ).to('cuda:0')

# train_GAN(
#     discriminator_loss(),
#     torch.nn.BCELoss(),
#     semi_supervised_loss(),
#     segmentor,
#     discriminator,
#     train_dl,
#     valid_dl,
#     unsegmented_raw,
#     2,
#     5,
#     save_path = '/home/aml334/CSE_MSE_RXF131/cradle-members/mds3/aml334'
# )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from unet import Unet
#       2 import importlib
#       3 import cv2
#
# ModuleNotFoundError: No module named 'unet'

# %%
# from sdlefleets.sdlefleets import run_sdlefleets

# # 5 python jobs
# #Need to add paraquet and estimate duration
# run_sdlefleets(job_name='unet_test_batch',
    # script_path='/home/aml334/CSE_MSE_RXF131/cradle-members/mds3/aml334/mds3-advman/packages/Unet_train/Usage/GAN_script_SDLE_Fleets.py',
    # parquet_path='/home/aml334/CSE_MSE_RXF131/cradle-members/mds3/aml334/GAN_MODELS_1/converted (1).parquet',
    # duration='07:00:00',
    # cpus=4,
    # partition='gpu',
    # ml_lib='-tf',
    # mem=32,
    # )
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
combined_df = pd.read_csv('/home/aml334/CSE_MSE_RXF131/lab-staging/mds3/AdvManu/fractography/combined_df.csv')
groups = combined_df.groupby(['Scan velocity (mm/s)','Scan Power (W)','σ max initiation (MPa)'])
max_difference_cycles = []
for name, group in groups:
    if(len(group)>2):
        print(group)
        no_retake = group[group['Retest']==float(0)]
        try:
            max_difference_cycles.append(no_retake['Cycles'].max()-no_retake['Cycles'].min())
        except ValueError:
            print('In group: '+str(name)+' something werid is going on')
plt.rcParams.update({'font.size': 16})  # Set font size for all elements
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.hist(max_difference_cycles,bins=50)
ax1.set_xlabel('Difference in Cycles to Failure')
ax1.set_ylabel('Count')
ax2.scatter(range(len(max_difference_cycles)),max_difference_cycles)
ax2.set_ylabel('Difference in Cycles to Failure')
ax2.set_xlabel('Conditions')
# Out:
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 79          250  CMU14-13-2    CMU14    13.0     2.0     0.0          ULI
# 105         256  CMU14-18-1    CMU14    18.0     1.0     0.0         STRI
# 114         279   CMU14-4-2    CMU14     4.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 79            280.0                 650.0                0.14  ...  NaN  NaN
# 105           280.0                 650.0                0.14  ...  NaN  NaN
# 114           280.0                 650.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 79      NaN              NaN             NaN           NaN
# 105     NaN              NaN             NaN           NaN
# 114     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 79                        NaN                             NaN           NaN
# 105                       NaN                             NaN           NaN
# 114                       NaN                             NaN           NaN
#
#      path_overload
# 79             NaN
# 105            NaN
# 114            NaN
#
# [3 rows x 74 columns]
#     Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 76         253  CMU14-16-1    CMU14    16.0     1.0     0.0         STRI
# 82         247  CMU14-12-1    CMU14    12.0     1.0     0.0          ULI
# 83         246  CMU14-11-2    CMU14    11.0     2.0     0.0          ULI
#
#     Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 76           280.0                 700.0                0.14  ...  NaN  NaN
# 82           280.0                 700.0                0.14  ...  NaN  NaN
# 83           280.0                 700.0                0.14  ...  NaN  NaN
#
#     F(a/b) path_valid_image path_initiation path_stitched  \
# 76     NaN              NaN             NaN           NaN
# 82     NaN              NaN             NaN           NaN
# 83     NaN              NaN             NaN           NaN
#
#     path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 76                       NaN                             NaN           NaN
# 82                       NaN                             NaN           NaN
# 83                       NaN                             NaN           NaN
#
#     path_overload
# 76            NaN
# 82            NaN
# 83            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 259         510   CMU5-1-1    CMU05     1.0     1.0     0.0          ULI
# 272         519  CMU5-19-2    CMU05    19.0     2.0     0.0          ULI
# 297         529  CMU5-29-2    CMU05    29.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 259           150.0                 730.0                0.14  ...  NaN  NaN
# 272           150.0                 730.0                0.14  ...  NaN  NaN
# 297           150.0                 730.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 259     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 272     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 297     NaN                                                NaN
#
#                                        path_initiation  \
# 259  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 272  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 297                                                NaN
#
#                                          path_stitched  \
# 259  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 272  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 297                                                NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 259                       NaN                             NaN           NaN
# 272                       NaN                             NaN           NaN
# 297                       NaN                             NaN           NaN
#
#      path_overload
# 259            NaN
# 272            NaN
# 297            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 93          268  CMU14-27-1    CMU14    27.0     1.0     0.0         STRI
# 95          266  CMU14-26-1    CMU14    26.0     1.0     0.0          ULI
# 100         261  CMU14-20-2    CMU14    20.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 93            280.0                 750.0                0.14  ...  NaN  NaN
# 95            280.0                 750.0                0.14  ...  NaN  NaN
# 100           280.0                 750.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 93      NaN              NaN             NaN           NaN
# 95      NaN              NaN             NaN           NaN
# 100     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 93                        NaN                             NaN           NaN
# 95                        NaN                             NaN           NaN
# 100                       NaN                             NaN           NaN
#
#      path_overload
# 93             NaN
# 95             NaN
# 100            NaN
#
# [3 rows x 74 columns]
#     Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 43         832  NASA1-34-3   NASA01     V34     3.0     0.0          ULI
# 46         829  NASA1-32-1   NASA01     V32     1.0     0.0          ULI
# 48         827  NASA1-31-2   NASA01     V31     2.0     0.0          ULI
#
#     Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 43           370.0                 800.0                 NaN  ...  NaN  NaN
# 46           370.0                 800.0                 NaN  ...  NaN  NaN
# 48           370.0                 800.0                 NaN  ...  NaN  NaN
#
#     F(a/b)                                   path_valid_image  \
# 43     NaN                                                NaN
# 46     NaN                                                NaN
# 48     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                       path_initiation  \
# 43                                                NaN
# 46                                                NaN
# 48  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                         path_stitched  \
# 43                                                NaN
# 46                                                NaN
# 48  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#     path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 43                       NaN                             NaN           NaN
# 46                       NaN                             NaN           NaN
# 48                       NaN                             NaN           NaN
#
#     path_overload
# 43            NaN
# 46            NaN
# 48            NaN
#
# [3 rows x 74 columns]
#     Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 44         831  NASA1-34-2   NASA01     V34     2.0     0.0          ULI
# 47         828  NASA1-31-3   NASA01     V31     3.0     0.0          ULI
# 49         826  NASA1-31-1   NASA01     V31     1.0     0.0          ULI
# 65          53   CMU1-32-2    CMU01    32.0     2.0     0.0          ULI
# 90          65    CMU1-9-1    CMU01     9.0     1.0     0.0          ULI
#
#     Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 44           370.0                 800.0                 NaN  ...  NaN  NaN
# 47           370.0                 800.0                 NaN  ...  NaN  NaN
# 49           370.0                 800.0                 NaN  ...  NaN  NaN
# 65           370.0                 800.0                0.14  ...  NaN  NaN
# 90           370.0                 800.0                0.14  ...  NaN  NaN
#
#     F(a/b)                                   path_valid_image  \
# 44     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 47     NaN                                                NaN
# 49     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 65     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 90     NaN                                                NaN
#
#                                       path_initiation  \
# 44  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 47                                                NaN
# 49  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 65  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 90                                                NaN
#
#                                         path_stitched  \
# 44  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 47                                                NaN
# 49  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 65  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 90                                                NaN
#
#     path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 44                       NaN                             NaN           NaN
# 47                       NaN                             NaN           NaN
# 49                       NaN                             NaN           NaN
# 65                       NaN                             NaN           NaN
# 90                       NaN                             NaN           NaN
#
#     path_overload
# 44            NaN
# 47            NaN
# 49            NaN
# 65            NaN
# 90            NaN
#
# [5 rows x 74 columns]
#     Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 34          57    CMU1-5-2    CMU01     5.0     2.0     1.0          ULI
# 45         830  NASA1-34-1   NASA01     V34     1.0     0.0          ULI
# 59          64    CMU1-8-2    CMU01     8.0     2.0     0.0          ULI
# 63          56    CMU1-5-1    CMU01     5.0     1.0     0.0          ULI
# 89          66    CMU1-9-2    CMU01     9.0     2.0     0.0          ULI
#
#     Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 34           370.0                 800.0                0.14  ...  NaN  NaN
# 45           370.0                 800.0                 NaN  ...  NaN  NaN
# 59           370.0                 800.0                0.14  ...  NaN  NaN
# 63           370.0                 800.0                0.14  ...  NaN  NaN
# 89           370.0                 800.0                0.14  ...  NaN  NaN
#
#     F(a/b)                                   path_valid_image  \
# 34     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 45     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 59     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 63     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 89     NaN                                                NaN
#
#                                       path_initiation  \
# 34  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 45  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 59  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 63  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 89                                                NaN
#
#                                         path_stitched  \
# 34  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 45  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 59  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 63                                                NaN
# 89                                                NaN
#
#     path_full_surface_marked  \
# 34                       NaN
# 45                       NaN
# 59                       NaN
# 63                       NaN
# 89                       NaN
#
#                        path_initation_marked_stitched  path_fatigue  \
# 34                                                NaN           NaN
# 45  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 59                                                NaN           NaN
# 63                                                NaN           NaN
# 89                                                NaN           NaN
#
#     path_overload
# 34            NaN
# 45            NaN
# 59            NaN
# 63            NaN
# 89            NaN
#
# [5 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 33           59   CMU1-6-1    CMU01     6.0     1.0     1.0          ULI
# 61           62   CMU1-7-2    CMU01     7.0     2.0     0.0          ULI
# 280          30  CMU1-21-2    CMU01    21.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 33            370.0                 850.0                0.14  ...  NaN  NaN
# 61            370.0                 850.0                0.14  ...  NaN  NaN
# 280           370.0                 850.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 33      NaN              NaN             NaN           NaN
# 61      NaN              NaN             NaN           NaN
# 280     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 33                        NaN                             NaN           NaN
# 61                        NaN                             NaN           NaN
# 280                       NaN                             NaN           NaN
#
#      path_overload
# 33             NaN
# 61             NaN
# 280            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 91          270  CMU14-29-1    CMU14    29.0     1.0     0.0         STRI
# 97          264  CMU14-22-1    CMU14    22.0     1.0     0.0          ULI
# 104         257  CMU14-19-1    CMU14    19.0     1.0     0.0          NaN
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 91            280.0                 900.0                0.14  ...  NaN  NaN
# 97            280.0                 900.0                0.14  ...  NaN  NaN
# 104           280.0                 900.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 91      NaN              NaN             NaN           NaN
# 97      NaN              NaN             NaN           NaN
# 104     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 91                        NaN                             NaN           NaN
# 97                        NaN                             NaN           NaN
# 104                       NaN                             NaN           NaN
#
#      path_overload
# 91             NaN
# 97             NaN
# 104            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 37            7  CMU1-12-2    CMU01    12.0     2.0     1.0          ULI
# 39            6  CMU1-12-1    CMU01    12.0     1.0     0.0          ULI
# 40            9  CMU1-13-1    CMU01    13.0     1.0     0.0          ULI
# 190          37  CMU1-25-1    CMU01    25.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 37            370.0                 900.0                0.14  ...  NaN  NaN
# 39            370.0                 900.0                0.14  ...  NaN  NaN
# 40            370.0                 900.0                0.14  ...  NaN  NaN
# 190           370.0                 900.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 37      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 39      NaN                                                NaN
# 40      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 190     NaN                                                NaN
#
#                                        path_initiation  \
# 37   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 39                                                 NaN
# 40   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 190                                                NaN
#
#                                          path_stitched  \
# 37   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 39                                                 NaN
# 40   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 190                                                NaN
#
#      path_full_surface_marked  \
# 37                        NaN
# 39                        NaN
# 40                        NaN
# 190                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 37   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 39                                                 NaN           NaN
# 40   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 190                                                NaN           NaN
#
#      path_overload
# 37             NaN
# 39             NaN
# 40             NaN
# 190            NaN
#
# [4 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 7            22  CMU1-19-1    CMU01    19.0     1.0     1.0          ULI
# 41           10  CMU1-13-2    CMU01    13.0     2.0     0.0          ULI
# 253          23  CMU1-19-2    CMU01    19.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 7             370.0                 900.0                0.14  ...  NaN  NaN
# 41            370.0                 900.0                0.14  ...  NaN  NaN
# 253           370.0                 900.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 7       NaN                                                NaN
# 41      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 253     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 7                                                  NaN
# 41   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 253  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 7                                                  NaN
# 41   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 253  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 7                         NaN
# 41                        NaN
# 253                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 7                                                  NaN           NaN
# 41   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 253  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
#
#      path_overload
# 7              NaN
# 41             NaN
# 253            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 77          252  CMU14-14-2    CMU14    14.0     2.0     0.0          ULI
# 88          241   CMU14-1-1    CMU14     1.0     1.0     0.0          ULI
# 118         275  CMU14-32-2    CMU14    32.0     2.0     0.0         STRI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 77            280.0                 950.0                0.14  ...  NaN  NaN
# 88            280.0                 950.0                0.14  ...  NaN  NaN
# 118           280.0                 950.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 77      NaN              NaN             NaN           NaN
# 88      NaN              NaN             NaN           NaN
# 118     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 77                        NaN                             NaN           NaN
# 88                        NaN                             NaN           NaN
# 118                       NaN                             NaN           NaN
#
#      path_overload
# 77             NaN
# 88             NaN
# 118            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 78          251  CMU14-14-1    CMU14    14.0     1.0     0.0          ULI
# 87          242   CMU14-1-2    CMU14     1.0     2.0     0.0          ULI
# 119         274  CMU14-32-1    CMU14    32.0     1.0     0.0         STRI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 78            280.0                 950.0                0.14  ...  NaN  NaN
# 87            280.0                 950.0                0.14  ...  NaN  NaN
# 119           280.0                 950.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 78      NaN              NaN             NaN           NaN
# 87      NaN              NaN             NaN           NaN
# 119     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 78                        NaN                             NaN           NaN
# 87                        NaN                             NaN           NaN
# 119                       NaN                             NaN           NaN
#
#      path_overload
# 78             NaN
# 87             NaN
# 119            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 71            1   CMU1-1-2    CMU01     1.0     2.0     0.0          ULI
# 191          36  CMU1-24-2    CMU01    24.0     2.0     0.0          ULI
# 216          44  CMU1-29-2    CMU01    29.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 71            370.0                 950.0                0.14  ...  NaN  NaN
# 191           370.0                 950.0                0.14  ...  NaN  NaN
# 216           370.0                 950.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 71      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 191     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 216     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 71   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 191  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 216  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 71   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 191  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 216  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 71                        NaN
# 191                       NaN
# 216                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 71                                                 NaN           NaN
# 191  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 216                                                NaN           NaN
#
#      path_overload
# 71             NaN
# 191            NaN
# 216            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 212          50  CMU1-31-2    CMU01    31.0     2.0     0.0          ULI
# 217          43  CMU1-29-1    CMU01    29.0     1.0     0.0          ULI
# 275          35  CMU1-24-1    CMU01    24.0     1.0     0.0          ULI
# 281           0   CMU1-1-1    CMU01     1.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 212           370.0                 950.0                0.14  ...  NaN  NaN
# 217           370.0                 950.0                0.14  ...  NaN  NaN
# 275           370.0                 950.0                0.14  ...  NaN  NaN
# 281           370.0                 950.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 212     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 217     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 275     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 281     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 212  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 217  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 275  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 281  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 212  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 217  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 275  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 281  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 212                       NaN
# 217                       NaN
# 275                       NaN
# 281                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 212                                                NaN           NaN
# 217                                                NaN           NaN
# 275  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 281                                                NaN           NaN
#
#      path_overload
# 212            NaN
# 217            NaN
# 275            NaN
# 281            NaN
#
# [4 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 85          244  CMU14-10-2    CMU14    10.0     2.0     0.0         STRI
# 86          243  CMU14-10-1    CMU14    10.0     1.0     0.0          ULI
# 120         273   CMU14-3-2    CMU14     3.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 85            280.0                1000.0                0.14  ...  NaN  NaN
# 86            280.0                1000.0                0.14  ...  NaN  NaN
# 120           280.0                1000.0                0.14  ...  NaN  NaN
#
#      F(a/b) path_valid_image path_initiation path_stitched  \
# 85      NaN              NaN             NaN           NaN
# 86      NaN              NaN             NaN           NaN
# 120     NaN              NaN             NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 85                        NaN                             NaN           NaN
# 86                        NaN                             NaN           NaN
# 120                       NaN                             NaN           NaN
#
#      path_overload
# 85             NaN
# 86             NaN
# 120            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 213          48  CMU1-30-2    CMU01    30.0     2.0     0.0         STRI
# 214          47  CMU1-30-1    CMU01    30.0     1.0     0.0         STRI
# 358           3  CMU1-10-2    CMU01    10.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 213           370.0                1000.0                0.14  ...  NaN  NaN
# 214           370.0                1000.0                0.14  ...  NaN  NaN
# 358           370.0                1000.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 213     NaN                                                NaN
# 214     NaN                                                NaN
# 358     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 213                                                NaN
# 214                                                NaN
# 358  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 213                                                NaN
# 214                                                NaN
# 358  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 213                       NaN                             NaN           NaN
# 214                       NaN                             NaN           NaN
# 358                       NaN                             NaN           NaN
#
#      path_overload
# 213            NaN
# 214            NaN
# 358            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 6            19  CMU1-17-2    CMU01    17.0     2.0     1.0          ULI
# 38            4  CMU1-11-1    CMU01    11.0     1.0     0.0          ULI
# 42           11  CMU1-14-1    CMU01    14.0     1.0     0.0          ULI
# 332           5  CMU1-11-2    CMU01    11.0     2.0     0.0          ULI
# 357          14  CMU1-15-1    CMU01    15.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 6             370.0                1050.0                0.14  ...  NaN  NaN
# 38            370.0                1050.0                0.14  ...  NaN  NaN
# 42            370.0                1050.0                0.14  ...  NaN  NaN
# 332           370.0                1050.0                0.14  ...  NaN  NaN
# 357           370.0                1050.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 6       NaN                                                NaN
# 38      NaN                                                NaN
# 42      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 332     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 357     NaN                                                NaN
#
#                                        path_initiation  \
# 6                                                  NaN
# 38                                                 NaN
# 42   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 332  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 357                                                NaN
#
#                                          path_stitched  \
# 6                                                  NaN
# 38                                                 NaN
# 42                                                 NaN
# 332  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 357                                                NaN
#
#      path_full_surface_marked  \
# 6                         NaN
# 38                        NaN
# 42                        NaN
# 332                       NaN
# 357                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 6                                                  NaN           NaN
# 38                                                 NaN           NaN
# 42                                                 NaN           NaN
# 332  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 357                                                NaN           NaN
#
#      path_overload
# 6              NaN
# 38             NaN
# 42             NaN
# 332            NaN
# 357            NaN
#
# [5 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 141         317  CMU15-7-2    CMU15     7.0     2.0     0.0          ULI
# 169         321  CMU15-9-2    CMU15     9.0     2.0     0.0          ULI
# 170         320  CMU15-9-1    CMU15     9.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 141           280.0                1100.0                0.14  ...  NaN  NaN
# 169           280.0                1100.0                0.14  ...  NaN  NaN
# 170           280.0                1100.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 141     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 169     NaN                                                NaN
# 170     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 141  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 169                                                NaN
# 170  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 141  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 169                                                NaN
# 170  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 141                       NaN                             NaN           NaN
# 169                       NaN                             NaN           NaN
# 170                       NaN                             NaN           NaN
#
#      path_overload
# 141            NaN
# 169            NaN
# 170            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 35           54   CMU1-4-1    CMU01     4.0     1.0     1.0          ULI
# 64           55   CMU1-4-2    CMU01     4.0     2.0     0.0          ULI
# 276          34  CMU1-23-2    CMU01    23.0     2.0     0.0          ULI
# 277          33  CMU1-23-1    CMU01    23.0     1.0     0.0          ULI
# 354          17  CMU1-16-2    CMU01    16.0     2.0     0.0          ULI
# 355          16  CMU1-16-1    CMU01    16.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 35            370.0                1100.0                0.14  ...  NaN  NaN
# 64            370.0                1100.0                0.14  ...  NaN  NaN
# 276           370.0                1100.0                0.14  ...  NaN  NaN
# 277           370.0                1100.0                0.14  ...  NaN  NaN
# 354           370.0                1100.0                0.14  ...  NaN  NaN
# 355           370.0                1100.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 35      NaN                                                NaN
# 64      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 276     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 277     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 354     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 355     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 35                                                 NaN
# 64   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 276  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 277  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 354  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 355  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 35                                                 NaN
# 64   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 276                                                NaN
# 277                                                NaN
# 354                                                NaN
# 355                                                NaN
#
#      path_full_surface_marked  \
# 35                        NaN
# 64                        NaN
# 276                       NaN
# 277                       NaN
# 354                       NaN
# 355                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 35                                                 NaN           NaN
# 64   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 276                                                NaN           NaN
# 277                                                NaN           NaN
# 354                                                NaN           NaN
# 355                                                NaN           NaN
#
#      path_overload
# 35             NaN
# 64             NaN
# 276            NaN
# 277            NaN
# 354            NaN
# 355            NaN
#
# [6 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 0            46   CMU1-3-2    CMU01     3.0     2.0     2.0          ULI
# 8            26   CMU1-2-2    CMU01     2.0     2.0     1.0          ULI
# 22           39  CMU1-27-1    CMU01    27.0     1.0     1.0          ULI
# 188          40  CMU1-27-2    CMU01    27.0     2.0     0.0          ULI
# 215          45   CMU1-3-1    CMU01     3.0     1.0     0.0          ULI
# 252          25   CMU1-2-1    CMU01     2.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 0             370.0                1150.0                0.14  ...  NaN  NaN
# 8             370.0                1150.0                0.14  ...  NaN  NaN
# 22            370.0                1150.0                0.14  ...  NaN  NaN
# 188           370.0                1150.0                0.14  ...  NaN  NaN
# 215           370.0                1150.0                0.14  ...  NaN  NaN
# 252           370.0                1150.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 0       NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 8       NaN                                                NaN
# 22      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 188     NaN                                                NaN
# 215     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 252     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 0    /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 8                                                  NaN
# 22   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 188                                                NaN
# 215  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 252  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 0    /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 8                                                  NaN
# 22   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 188                                                NaN
# 215  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 252  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 0                         NaN
# 8                         NaN
# 22                        NaN
# 188                       NaN
# 215                       NaN
# 252                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 0                                                  NaN           NaN
# 8                                                  NaN           NaN
# 22   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 188                                                NaN           NaN
# 215  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 252                                                NaN           NaN
#
#      path_overload
# 0              NaN
# 8              NaN
# 22             NaN
# 188            NaN
# 215            NaN
# 252            NaN
#
# [6 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 4           868  NASA1-E4-1   NASA01     VE4     1.0     1.0          ULI
# 144         313   CMU15-5-1    CMU15     5.0     1.0     0.0          ULI
# 333         867  NASA1-E2-1   NASA01     VE2     1.0     0.0          ULI
# 346         869  NASA1-E4-2   NASA01     VE4     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 4             280.0                1200.0                 NaN  ...  NaN  NaN
# 144           280.0                1200.0                0.14  ...  NaN  NaN
# 333           280.0                1200.0                 NaN  ...  NaN  NaN
# 346           280.0                1200.0                 NaN  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 4       NaN                                                NaN
# 144     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 333     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 346     NaN                                                NaN
#
#                                        path_initiation  \
# 4                                                  NaN
# 144  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 333  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 346                                                NaN
#
#                                          path_stitched  \
# 4                                                  NaN
# 144  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 333  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 346                                                NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 4                         NaN                             NaN           NaN
# 144                       NaN                             NaN           NaN
# 333                       NaN                             NaN           NaN
# 346                       NaN                             NaN           NaN
#
#      path_overload
# 4              NaN
# 144            NaN
# 333            NaN
# 346            NaN
#
# [4 rows x 74 columns]
#      Unnamed: 0   Sample# Build ID Build #  Test #  Retest Project Name  \
# 168         343  CMU2-1-1    CMU02     1.0     1.0     0.0          ULI
# 209         401  CMU2-9-1    CMU02     9.0     1.0     0.0          ULI
# 296         530  CMU5-3-1    CMU05     3.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 168           370.0                1200.0                0.14  ...  NaN  NaN
# 209           370.0                1200.0                0.14  ...  NaN  NaN
# 296           370.0                1200.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 168     NaN                                                NaN
# 209     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 296     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 168                                                NaN
# 209  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 296  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 168                                                NaN
# 209                                                NaN
# 296  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 168                       NaN                             NaN           NaN
# 209                       NaN                             NaN           NaN
# 296                       NaN                             NaN           NaN
#
#      path_overload
# 168            NaN
# 209            NaN
# 296            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 176         378  CMU2-26-2    CMU02    26.0     2.0     0.0          ULI
# 177         377  CMU2-26-1    CMU02    26.0     1.0     0.0          ULI
# 208         402   CMU2-9-2    CMU02     9.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 176           370.0                1200.0                0.14  ...  NaN  NaN
# 177           370.0                1200.0                0.14  ...  NaN  NaN
# 208           370.0                1200.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 176     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 177     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 208     NaN                                                NaN
#
#                                        path_initiation path_stitched  \
# 176  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 177  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 208                                                NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 176                       NaN                             NaN           NaN
# 177                       NaN                             NaN           NaN
# 208                       NaN                             NaN           NaN
#
#      path_overload
# 176            NaN
# 177            NaN
# 208            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 159         352  CMU2-14-2    CMU02    14.0     2.0     0.0          ULI
# 160         351  CMU2-14-1    CMU02    14.0     1.0     0.0          ULI
# 167         344  CMU2-10-1    CMU02    10.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 159           370.0                1250.0                0.14  ...  NaN  NaN
# 160           370.0                1250.0                0.14  ...  NaN  NaN
# 167           370.0                1250.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 159     NaN                                                NaN
# 160     NaN                                                NaN
# 167     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation path_stitched  \
# 159                                                NaN           NaN
# 160                                                NaN           NaN
# 167  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 159                       NaN                             NaN           NaN
# 160                       NaN                             NaN           NaN
# 167                       NaN                             NaN           NaN
#
#      path_overload
# 159            NaN
# 160            NaN
# 167            NaN
#
# [3 rows x 74 columns]
# ...
# 241           370.0                1700.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 221     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 231     NaN                                                NaN
# 241     NaN                                                NaN
#
#                                        path_initiation path_stitched  \
# 221  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 231                                                NaN           NaN
# 241                                                NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 221                       NaN                             NaN           NaN
# 231                       NaN                             NaN           NaN
# 241                       NaN                             NaN           NaN
#
#      path_overload
# 221            NaN
# 231            NaN
# 241            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 36          845  NASA1-54-3   NASA01     V54     3.0     1.0          ULI
# 230         415   CMU3-16-1    CMU03    16.0     1.0     0.0          ULI
# 245         433   CMU3-25-1    CMU03    25.0     1.0     0.0          ULI
# 263         452    CMU3-5-2    CMU03     5.0     2.0     0.0          ULI
# 347         844  NASA1-54-2   NASA01     V54     2.0     0.0          ULI
# 350         841  NASA1-53-1   NASA01     V53     1.0     0.0          ULI
# 351         840  NASA1-52-1   NASA01     V52     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 36            370.0                1800.0                 NaN  ...  NaN  NaN
# 230           370.0                1800.0                0.14  ...  NaN  NaN
# 245           370.0                1800.0                0.14  ...  NaN  NaN
# 263           370.0                1800.0                0.14  ...  NaN  NaN
# 347           370.0                1800.0                 NaN  ...  NaN  NaN
# 350           370.0                1800.0                 NaN  ...  NaN  NaN
# 351           370.0                1800.0                 NaN  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 36      NaN                                                NaN
# 230     NaN                                                NaN
# 245     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 263     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 347     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 350     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 351     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 36                                                 NaN
# 230                                                NaN
# 245  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 263  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 347                                                NaN
# 350  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 351  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 36                                                 NaN
# 230                                                NaN
# 245  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 263  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 347  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 350  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 351  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 36                        NaN
# 230                       NaN
# 245                       NaN
# 263                       NaN
# 347                       NaN
# 350                       NaN
# 351                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 36                                                 NaN           NaN
# 230                                                NaN           NaN
# 245                                                NaN           NaN
# 263  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 347                                                NaN           NaN
# 350                                                NaN           NaN
# 351                                                NaN           NaN
#
#      path_overload
# 36             NaN
# 230            NaN
# 245            NaN
# 263            NaN
# 347            NaN
# 350            NaN
# 351            NaN
#
# [7 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 1           434   CMU3-25-2    CMU03    25.0     2.0     2.0          ULI
# 11          451    CMU3-5-1    CMU03     5.0     1.0     1.0          ULI
# 229         416   CMU3-16-2    CMU03    16.0     2.0     0.0          ULI
# 237         443   CMU3-30-2    CMU03    30.0     2.0     0.0          ULI
# 348         843  NASA1-54-1   NASA01     V54     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 1             370.0                1800.0                0.14  ...  NaN  NaN
# 11            370.0                1800.0                0.14  ...  NaN  NaN
# 229           370.0                1800.0                0.14  ...  NaN  NaN
# 237           370.0                1800.0                0.14  ...  NaN  NaN
# 348           370.0                1800.0                 NaN  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 1       NaN                                                NaN
# 11      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 229     NaN                                                NaN
# 237     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 348     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 1                                                  NaN
# 11   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 229                                                NaN
# 237  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 348  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 1                                                  NaN
# 11   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 229                                                NaN
# 237  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 348  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 1                         NaN
# 11                        NaN
# 229                       NaN
# 237                       NaN
# 348                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 1                                                  NaN           NaN
# 11                                                 NaN           NaN
# 229                                                NaN           NaN
# 237                                                NaN           NaN
# 348  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
#
#      path_overload
# 1              NaN
# 11             NaN
# 229            NaN
# 237            NaN
# 348            NaN
#
# [5 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 12          445  CMU3-31-2    CMU03    31.0     2.0     1.0          ULI
# 224         421  CMU3-19-1    CMU03    19.0     1.0     0.0          ULI
# 236         444  CMU3-31-1    CMU03    31.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 12            370.0                1850.0                0.14  ...  NaN  NaN
# 224           370.0                1850.0                0.14  ...  NaN  NaN
# 236           370.0                1850.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 12      NaN                                                NaN
# 224     NaN                                                NaN
# 236     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                        path_initiation  \
# 12                                                 NaN
# 224                                                NaN
# 236  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#                                          path_stitched  \
# 12                                                 NaN
# 224                                                NaN
# 236  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
#
#      path_full_surface_marked  \
# 12                        NaN
# 224                       NaN
# 236                       NaN
#
#                         path_initation_marked_stitched  path_fatigue  \
# 12                                                 NaN           NaN
# 224                                                NaN           NaN
# 236  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
#
#      path_overload
# 12             NaN
# 224            NaN
# 236            NaN
#
# [3 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 16          405  CMU3-10-1    CMU03    10.0     1.0     1.0          ULI
# 205         406  CMU3-10-2    CMU03    10.0     2.0     0.0          ULI
# 234         410  CMU3-13-2    CMU03    13.0     2.0     0.0          ULI
# 243         437  CMU3-26-2    CMU03    26.0     2.0     0.0          ULI
# 262         453   CMU3-6-1    CMU03     6.0     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 16            370.0                1900.0                0.14  ...  NaN  NaN
# 205           370.0                1900.0                0.14  ...  NaN  NaN
# 234           370.0                1900.0                0.14  ...  NaN  NaN
# 243           370.0                1900.0                0.14  ...  NaN  NaN
# 262           370.0                1900.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 16      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 205     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 234     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 243     NaN                                                NaN
# 262     NaN                                                NaN
#
#                                        path_initiation  \
# 16   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 205  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 234  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 243                                                NaN
# 262                                                NaN
#
#                                          path_stitched  \
# 16   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 205                                                NaN
# 234  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 243                                                NaN
# 262                                                NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 16                        NaN                             NaN           NaN
# 205                       NaN                             NaN           NaN
# 234                       NaN                             NaN           NaN
# 243                       NaN                             NaN           NaN
# 262                       NaN                             NaN           NaN
#
#      path_overload
# 16             NaN
# 205            NaN
# 234            NaN
# 243            NaN
# 262            NaN
#
# [5 rows x 74 columns]
#      Unnamed: 0    Sample# Build ID Build #  Test #  Retest Project Name  \
# 17          408  CMU3-12-2    CMU03    12.0     2.0     1.0          ULI
# 204         407  CMU3-12-1    CMU03    12.0     1.0     0.0          ULI
# 249         428  CMU3-21-2    CMU03    21.0     2.0     0.0          ULI
# 264         450   CMU3-4-2    CMU03     4.0     2.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 17            370.0                1950.0                0.14  ...  NaN  NaN
# 204           370.0                1950.0                0.14  ...  NaN  NaN
# 249           370.0                1950.0                0.14  ...  NaN  NaN
# 264           370.0                1950.0                0.14  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 17      NaN                                                NaN
# 204     NaN                                                NaN
# 249     NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 264     NaN                                                NaN
#
#                                        path_initiation path_stitched  \
# 17                                                 NaN           NaN
# 204                                                NaN           NaN
# 249  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...           NaN
# 264                                                NaN           NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 17                        NaN                             NaN           NaN
# 204                       NaN                             NaN           NaN
# 249                       NaN                             NaN           NaN
# 264                       NaN                             NaN           NaN
#
#      path_overload
# 17             NaN
# 204            NaN
# 249            NaN
# 264            NaN
#
# [4 rows x 74 columns]
#      Unnamed: 0     Sample# Build ID Build #  Test #  Retest Project Name  \
# 66          855  NASA1-82-1   NASA01     V82     1.0     0.0          ULI
# 338         862  NASA1-84-2   NASA01     V84     2.0     0.0          ULI
# 339         861  NASA1-84-1   NASA01     V84     1.0     0.0          ULI
#
#      Scan Power (W)  Scan velocity (mm/s)  Hatch Spacing (mm)  ...  Mpa  a/b  \
# 66            370.0                3000.0                 NaN  ...  NaN  NaN
# 338           370.0                3000.0                 NaN  ...  NaN  NaN
# 339           370.0                3000.0                 NaN  ...  NaN  NaN
#
#      F(a/b)                                   path_valid_image  \
# 66      NaN  /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 338     NaN                                                NaN
# 339     NaN                                                NaN
#
#                                        path_initiation  \
# 66   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 338                                                NaN
# 339                                                NaN
#
#                                          path_stitched  \
# 66   /mnt/vstor/CSE_MSE_RXF131/lab-staging/mds3/Adv...
# 338                                                NaN
# 339                                                NaN
#
#      path_full_surface_marked  path_initation_marked_stitched  path_fatigue  \
# 66                        NaN                             NaN           NaN
# 338                       NaN                             NaN           NaN
# 339                       NaN                             NaN           NaN
#
#      path_overload
# 66             NaN
# 338            NaN
# 339            NaN
#
# [3 rows x 74 columns]
# Text(0.5, 0, 'Conditions')
